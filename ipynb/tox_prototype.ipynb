# %% [markdown]
# # Tox Prototype
#
# Before running [`tox.ini`](../tox.ini) with a matrix of tests vs Python versions it is wise to manually run the same testing in your development environment.
#
# ## Development Environment
#
# The recommended development (__dev__) environment:
#
# - Python 3.10
# - requirements_dev.txt         # must have
# - requirements_user.txt        # nice to have
#   - requirements-test-min.txt  # benchmark (do this from tox)
#   - requirements-test.txt      # testing (do this from tox)
#
# > Note: The [`Dockfile`](../.devcontainer/Dockerfile) loads all three of these `requirements-*.txt` files into the [`devcontianer`](../.devcontainer/devcontainer.json).

# %% [markdown]
# ---
#
# ## [`tox.ini`](../tox.ini)
#
# This is a 'developers' version with the following perspective:
#
# - py39 only
#   - use this notebook to manually check py310
#   - no plan to support py38 or earlier
#
# ---
#
# ## Test: `pytest` and `coverage`
#
# __[testenv]__
#
# Looking for broken code to the extent necessary for development.
#
# Minimal Requirements:
#
# - fix all broken tests
# - create new tests to cover new behavior
# - maintain ~40% at all times during development

# %%
# versions used for testing ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! python --version
! coverage --version
! pytest --version
# Out:
# Python 3.10.4
# Coverage.py, version 6.3.2 with C extension
# Full documentation is at https://coverage.readthedocs.io
# pytest 7.1.2

# %%
# pytest only ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && pytest tests/test_*.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.4, pytest-7.1.2, pluggy-1.0.0
# rootdir: /workspaces/ruamel-yaml-dev
# plugins: anyio-3.5.0
# collected 420 items
#
# tests/test_a_dedent.py ......                                            [  1%]
# tests/test_add_xxx.py .......                                            [  3%]
# tests/test_anchor.py ............................                        [  9%]
# tests/test_api_change.py ..................s                             [ 14%]
# tests/test_class_register.py ........                                    [ 16%]
# tests/test_collections.py .                                              [ 16%]
# tests/test_comment_manipulation.py ..........................            [ 22%]
# tests/test_comments.py ........................................x........ [ 34%]
# ..................                                                       [ 38%]
# tests/test_contextmanager.py ........                                    [ 40%]
# tests/test_copy.py .....                                                 [ 41%]
# tests/test_cyaml.py .s..                                                 [ 42%]
# tests/test_datetime.py ...............                                   [ 46%]
# tests/test_deprecation.py s                                              [ 46%]
# tests/test_documents.py ......                                           [ 47%]
# tests/test_fail.py x.x.x.x.......                                        [ 51%]
# tests/test_float.py ....                                                 [ 52%]
# tests/test_flowsequencekey.py .                                          [ 52%]
# tests/test_indentation.py ..........................                     [ 58%]
# tests/test_int.py .                                                      [ 58%]
# tests/test_issues.py ................................................... [ 70%]
#                                                                          [ 70%]
# tests/test_json_numbers.py ..                                            [ 71%]
# tests/test_line_col.py .......                                           [ 73%]
# tests/test_literal.py .........................                          [ 79%]
# tests/test_none.py .....                                                 [ 80%]
# tests/test_program_config.py ...                                         [ 80%]
# tests/test_spec_examples.py .x.xxxx..xxxxxx.xxxx                         [ 85%]
# tests/test_string.py ................                                    [ 89%]
# tests/test_tag.py ......xx......                                         [ 92%]
# tests/test_version.py ........                                           [ 94%]
# tests/test_yamlfile.py ....s.........                                    [ 98%]
# tests/test_yamlobject.py ...                                             [ 98%]
# tests/test_z_check_debug_leftovers.py ..                                 [ 99%]
# tests/test_z_data.py s                                                   [ 99%]
# tests/test_z_olddata.py ..                                               [100%]
#
# ================= 393 passed, 5 skipped, 22 xfailed in 31.04s ==================

# %%
# pytest and coverage ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && pytest --cov
# Out:
# ERROR: usage: pytest [options] [file_or_dir] [file_or_dir] [...]
# pytest: error: unrecognized arguments: --cov
#   inifile: None
#   rootdir: /workspaces/ruamel-yaml-dev

# %% [markdown]
# ---
#
# ## Linters: `flake8`, `isort`, `black`, and `twine`
#
# __[testenv:linters]__
#
# Lint - Readability and style enforcement.
#
# Minimal Requirements:
#
# - fix all warnings

# %%
# versions used for testing ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! python --version
! flake8 --version
! isort --version
! black --version
! twine --version
# Out:
# Python 3.10.4
# 4.0.1 (flake8-bugbear: 22.3.23, flake8-docstrings: 1.6.0, pydocstyle: 6.1.1,
# flake8_typing_imports: 1.12.0, mccabe: 0.6.1, naming: 0.12.1, pycodestyle:
# 2.8.0, pyflakes: 2.4.0) CPython 3.10.4 on Linux
#
#                  _                 _
#                 (_) ___  ___  _ __| |_
#                 | |/ _/ / _ \/ '__  _/
#                 | |\__ \/\_\/| |  | |_
#                 |_|\___/\___/\_/   \_/
#
#       isort your imports, so you don't have to.
#
#                     VERSION 5.10.1
#
# black, 22.3.0 (compiled: yes)
# twine version 4.0.0 (importlib-metadata: 4.11.3, keyring: 23.5.0, pkginfo:
# 1.8.2, requests: 2.27.1, requests-toolbelt: 0.9.1, urllib3: 1.26.9)

# %% [markdown]
# ---
#
# ### `flake8`

# %%
# flake8 all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 pydantic tests setup.py
# Out:
# pydantic:0:1: E902 FileNotFoundError: [Errno 2] No such file or directory: 'pydantic'
# tests/roundtrip.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/roundtrip.py:3:1: D400 First line should end with a period
# tests/roundtrip.py:14:1: D103 Missing docstring in public function
# tests/roundtrip.py:23:50: E203 whitespace before ':'
# tests/roundtrip.py:27:1: D103 Missing docstring in public function
# tests/roundtrip.py:37:1: D103 Missing docstring in public function
# tests/roundtrip.py:47:1: D103 Missing docstring in public function
# tests/roundtrip.py:80:1: D103 Missing docstring in public function
# tests/roundtrip.py:113:1: D103 Missing docstring in public function
# tests/roundtrip.py:142:1: D205 1 blank line required between summary line and description
# tests/roundtrip.py:142:1: D400 First line should end with a period
# tests/roundtrip.py:203:1: D205 1 blank line required between summary line and description
# tests/roundtrip.py:203:1: D400 First line should end with a period
# tests/roundtrip.py:236:1: D103 Missing docstring in public function
# tests/roundtrip.py:236:6: N802 function name 'YAML' should be lowercase
# tests/roundtrip.py:240:1: D400 First line should end with a period
# tests/roundtrip.py:314:80: E501 line too long (87 > 79 characters)
# tests/roundtrip.py:315:1: D205 1 blank line required between summary line and description
# tests/roundtrip.py:315:1: D400 First line should end with a period
# tests/roundtrip.py:315:1: D403 First word of the first line should be properly capitalized
# tests/roundtrip.py:316:80: E501 line too long (89 > 79 characters)
# tests/roundtrip.py:335:80: E501 line too long (90 > 79 characters)
# tests/roundtrip.py:345:80: E501 line too long (85 > 79 characters)
# tests/test_add_xxx.py:1:1: D100 Missing docstring in public module
# tests/test_add_xxx.py:10:1: D101 Missing docstring in public class
# tests/test_add_xxx.py:11:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:14:1: D105 Missing docstring in magic method
# tests/test_add_xxx.py:18:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:24:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:28:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:37:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:41:80: E501 line too long (85 > 79 characters)
# tests/test_add_xxx.py:46:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:58:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:71:1: D101 Missing docstring in public class
# tests/test_add_xxx.py:72:1: D107 Missing docstring in __init__
# tests/test_add_xxx.py:76:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:79:1: D105 Missing docstring in magic method
# tests/test_add_xxx.py:82:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:86:1: D101 Missing docstring in public class
# tests/test_add_xxx.py:90:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:101:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:102:80: E501 line too long (80 > 79 characters)
# tests/test_add_xxx.py:105:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:118:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:122:80: E501 line too long (82 > 79 characters)
# tests/test_add_xxx.py:140:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:157:80: E501 line too long (82 > 79 characters)
# tests/test_add_xxx.py:161:80: E501 line too long (86 > 79 characters)
# tests/test_anchor.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_anchor.py:3:1: D400 First line should end with a period
# tests/test_anchor.py:14:1: D103 Missing docstring in public function
# tests/test_anchor.py:18:1: D103 Missing docstring in public function
# tests/test_anchor.py:22:1: D101 Missing docstring in public class
# tests/test_anchor.py:23:1: D102 Missing docstring in public method
# tests/test_anchor.py:44:1: D400 First line should end with a period
# tests/test_anchor.py:44:1: D403 First word of the first line should be properly capitalized
# tests/test_anchor.py:62:1: D102 Missing docstring in public method
# tests/test_anchor.py:83:1: D102 Missing docstring in public method
# tests/test_anchor.py:109:80: E501 line too long (93 > 79 characters)
# tests/test_anchor.py:111:1: D102 Missing docstring in public method
# tests/test_anchor.py:123:1: D102 Missing docstring in public method
# tests/test_anchor.py:168:1: D102 Missing docstring in public method
# tests/test_anchor.py:184:1: D102 Missing docstring in public method
# tests/test_anchor.py:199:1: D102 Missing docstring in public method
# tests/test_anchor.py:203:1: D102 Missing docstring in public method
# tests/test_anchor.py:215:1: D102 Missing docstring in public method
# tests/test_anchor.py:228:1: D102 Missing docstring in public method
# tests/test_anchor.py:249:1: D102 Missing docstring in public method
# tests/test_anchor.py:263:1: D102 Missing docstring in public method
# tests/test_anchor.py:286:80: E501 line too long (80 > 79 characters)
# tests/test_anchor.py:288:1: D102 Missing docstring in public method
# tests/test_anchor.py:312:80: E501 line too long (80 > 79 characters)
# tests/test_anchor.py:315:1: D101 Missing docstring in public class
# tests/test_anchor.py:334:1: D102 Missing docstring in public method
# tests/test_anchor.py:345:1: D102 Missing docstring in public method
# tests/test_anchor.py:356:1: D102 Missing docstring in public method
# tests/test_anchor.py:367:1: D102 Missing docstring in public method
# tests/test_anchor.py:378:1: D102 Missing docstring in public method
# tests/test_anchor.py:398:1: D102 Missing docstring in public method
# tests/test_anchor.py:436:1: D102 Missing docstring in public method
# tests/test_anchor.py:443:1: D102 Missing docstring in public method
# tests/test_anchor.py:463:1: D101 Missing docstring in public class
# tests/test_anchor.py:464:1: D102 Missing docstring in public method
# tests/test_anchor.py:467:80: E501 line too long (88 > 79 characters)
# tests/test_anchor.py:489:1: D102 Missing docstring in public method
# tests/test_anchor.py:513:1: D101 Missing docstring in public class
# tests/test_anchor.py:514:1: D102 Missing docstring in public method
# tests/test_anchor.py:525:1: D102 Missing docstring in public method
# tests/test_anchor.py:534:1: D102 Missing docstring in public method
# tests/test_anchor.py:540:80: E501 line too long (80 > 79 characters)
# tests/test_api_change.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_api_change.py:3:1: D400 First line should end with a period
# tests/test_api_change.py:13:1: D101 Missing docstring in public class
# tests/test_api_change.py:14:1: D102 Missing docstring in public method
# tests/test_api_change.py:22:1: D102 Missing docstring in public method
# tests/test_api_change.py:30:1: D102 Missing docstring in public method
# tests/test_api_change.py:38:1: D102 Missing docstring in public method
# tests/test_api_change.py:47:1: D102 Missing docstring in public method
# tests/test_api_change.py:56:1: D101 Missing docstring in public class
# tests/test_api_change.py:57:1: D102 Missing docstring in public method
# tests/test_api_change.py:68:1: D102 Missing docstring in public method
# tests/test_api_change.py:80:1: D102 Missing docstring in public method
# tests/test_api_change.py:90:1: D102 Missing docstring in public method
# tests/test_api_change.py:101:1: D102 Missing docstring in public method
# tests/test_api_change.py:115:1: D102 Missing docstring in public method
# tests/test_api_change.py:127:1: D101 Missing docstring in public class
# tests/test_api_change.py:128:1: D102 Missing docstring in public method
# tests/test_api_change.py:136:1: D102 Missing docstring in public method
# tests/test_api_change.py:152:1: D101 Missing docstring in public class
# tests/test_api_change.py:154:1: D400 First line should end with a period
# tests/test_api_change.py:154:1: D403 First word of the first line should be properly capitalized
# tests/test_api_change.py:154:80: E501 line too long (82 > 79 characters)
# tests/test_api_change.py:171:1: D101 Missing docstring in public class
# tests/test_api_change.py:172:1: D102 Missing docstring in public method
# tests/test_api_change.py:190:1: D101 Missing docstring in public class
# tests/test_api_change.py:191:80: E501 line too long (92 > 79 characters)
# tests/test_api_change.py:193:1: D102 Missing docstring in public method
# tests/test_api_change.py:200:80: E501 line too long (85 > 79 characters)
# tests/test_api_change.py:202:1: D102 Missing docstring in public method
# tests/test_api_change.py:213:1: D101 Missing docstring in public class
# tests/test_api_change.py:214:1: D102 Missing docstring in public method
# tests/test_api_change.py:228:1: D101 Missing docstring in public class
# tests/test_api_change.py:230:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:1:1: D100 Missing docstring in public module
# tests/test_a_dedent.py:6:1: D101 Missing docstring in public class
# tests/test_a_dedent.py:7:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:16:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:25:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:33:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:38:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:43:1: D102 Missing docstring in public method
# tests/test_class_register.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_class_register.py:3:1: D400 First line should end with a period
# tests/test_class_register.py:10:1: D101 Missing docstring in public class
# tests/test_class_register.py:11:1: D107 Missing docstring in __init__
# tests/test_class_register.py:16:1: D101 Missing docstring in public class
# tests/test_class_register.py:19:1: D107 Missing docstring in __init__
# tests/test_class_register.py:24:1: D102 Missing docstring in public method
# tests/test_class_register.py:25:80: E501 line too long (94 > 79 characters)
# tests/test_class_register.py:28:1: D102 Missing docstring in public method
# tests/test_class_register.py:32:1: D101 Missing docstring in public class
# tests/test_class_register.py:33:1: D102 Missing docstring in public method
# tests/test_class_register.py:44:1: D102 Missing docstring in public method
# tests/test_class_register.py:54:1: D102 Missing docstring in public method
# tests/test_class_register.py:64:1: D102 Missing docstring in public method
# tests/test_class_register.py:73:1: D102 Missing docstring in public method
# tests/test_class_register.py:82:1: D102 Missing docstring in public method
# tests/test_class_register.py:92:1: D101 Missing docstring in public class
# tests/test_class_register.py:93:1: D102 Missing docstring in public method
# tests/test_class_register.py:112:1: D102 Missing docstring in public method
# tests/test_collections.py:3:1: D400 First line should end with a period
# tests/test_collections.py:4:80: E501 line too long (90 > 79 characters)
# tests/test_collections.py:16:1: D101 Missing docstring in public class
# tests/test_collections.py:17:1: D102 Missing docstring in public method
# tests/test_comments.py:3:1: D205 1 blank line required between summary line and description
# tests/test_comments.py:3:1: D400 First line should end with a period
# tests/test_comments.py:19:1: D101 Missing docstring in public class
# tests/test_comments.py:21:1: D205 1 blank line required between summary line and description
# tests/test_comments.py:21:1: D209 Multi-line docstring closing quotes should be on a separate line
# tests/test_comments.py:21:1: D301 Use r""" if any backslashes in a docstring
# tests/test_comments.py:21:1: D400 First line should end with a period
# tests/test_comments.py:21:1: D403 First word of the first line should be properly capitalized
# tests/test_comments.py:29:1: D102 Missing docstring in public method
# tests/test_comments.py:37:1: D102 Missing docstring in public method
# tests/test_comments.py:49:1: D102 Missing docstring in public method
# tests/test_comments.py:57:1: D102 Missing docstring in public method
# tests/test_comments.py:65:1: D102 Missing docstring in public method
# tests/test_comments.py:76:1: D102 Missing docstring in public method
# tests/test_comments.py:90:1: D102 Missing docstring in public method
# tests/test_comments.py:101:1: D102 Missing docstring in public method
# tests/test_comments.py:112:1: D102 Missing docstring in public method
# tests/test_comments.py:123:1: D102 Missing docstring in public method
# tests/test_comments.py:136:1: D102 Missing docstring in public method
# tests/test_comments.py:148:1: D102 Missing docstring in public method
# tests/test_comments.py:159:1: D102 Missing docstring in public method
# tests/test_comments.py:167:1: D102 Missing docstring in public method
# tests/test_comments.py:175:1: D102 Missing docstring in public method
# tests/test_comments.py:184:1: D102 Missing docstring in public method
# tests/test_comments.py:197:1: D102 Missing docstring in public method
# tests/test_comments.py:214:1: D102 Missing docstring in public method
# tests/test_comments.py:225:1: D102 Missing docstring in public method
# tests/test_comments.py:234:1: D102 Missing docstring in public method
# tests/test_comments.py:244:1: D102 Missing docstring in public method
# tests/test_comments.py:266:1: D102 Missing docstring in public method
# tests/test_comments.py:281:1: D102 Missing docstring in public method
# tests/test_comments.py:296:1: D102 Missing docstring in public method
# tests/test_comments.py:313:1: D205 1 blank line required between summary line and description
# tests/test_comments.py:313:1: D209 Multi-line docstring closing quotes should be on a separate line
# tests/test_comments.py:313:1: D400 First line should end with a period
# tests/test_comments.py:317:1: D102 Missing docstring in public method
# tests/test_comments.py:330:1: D102 Missing docstring in public method
# tests/test_comments.py:347:1: D102 Missing docstring in public method
# tests/test_comments.py:364:1: D102 Missing docstring in public method
# tests/test_comments.py:381:1: D102 Missing docstring in public method
# tests/test_comments.py:397:1: D102 Missing docstring in public method
# tests/test_comments.py:413:1: D102 Missing docstring in public method
# tests/test_comments.py:429:1: D102 Missing docstring in public method
# tests/test_comments.py:447:1: D101 Missing docstring in public class
# tests/test_comments.py:449:1: D102 Missing docstring in public method
# tests/test_comments.py:456:1: D102 Missing docstring in public method
# tests/test_comments.py:468:1: D102 Missing docstring in public method
# tests/test_comments.py:480:1: D102 Missing docstring in public method
# tests/test_comments.py:494:1: D101 Missing docstring in public class
# tests/test_comments.py:495:1: D102 Missing docstring in public method
# tests/test_comments.py:511:1: D102 Missing docstring in public method
# tests/test_comments.py:522:1: D102 Missing docstring in public method
# tests/test_comments.py:535:1: D101 Missing docstring in public class
# tests/test_comments.py:537:1: D102 Missing docstring in public method
# tests/test_comments.py:552:1: D102 Missing docstring in public method
# tests/test_comments.py:568:1: D102 Missing docstring in public method
# tests/test_comments.py:584:1: D102 Missing docstring in public method
# tests/test_comments.py:592:1: D102 Missing docstring in public method
# tests/test_comments.py:601:1: D102 Missing docstring in public method
# tests/test_comments.py:613:1: D102 Missing docstring in public method
# tests/test_comments.py:624:1: D102 Missing docstring in public method
# tests/test_comments.py:635:1: D102 Missing docstring in public method
# tests/test_comments.py:648:1: D102 Missing docstring in public method
# tests/test_comments.py:658:1: D102 Missing docstring in public method
# tests/test_comments.py:667:1: D102 Missing docstring in public method
# tests/test_comments.py:675:1: D102 Missing docstring in public method
# tests/test_comments.py:682:1: D102 Missing docstring in public method
# tests/test_comments.py:690:1: D102 Missing docstring in public method
# tests/test_comments.py:703:1: D101 Missing docstring in public class
# tests/test_comments.py:705:1: D102 Missing docstring in public method
# tests/test_comments.py:724:1: D101 Missing docstring in public class
# tests/test_comments.py:725:1: D102 Missing docstring in public method
# tests/test_comments.py:733:1: D102 Missing docstring in public method
# tests/test_comments.py:741:1: D102 Missing docstring in public method
# tests/test_comments.py:747:1: D102 Missing docstring in public method
# tests/test_comments.py:755:1: D102 Missing docstring in public method
# tests/test_comments.py:764:1: D102 Missing docstring in public method
# tests/test_comments.py:771:1: D102 Missing docstring in public method
# tests/test_comments.py:779:1: D102 Missing docstring in public method
# tests/test_comments.py:786:1: D102 Missing docstring in public method
# tests/test_comments.py:794:1: D102 Missing docstring in public method
# tests/test_comments.py:801:1: D102 Missing docstring in public method
# tests/test_comments.py:816:1: D102 Missing docstring in public method
# tests/test_comments.py:835:1: D101 Missing docstring in public class
# tests/test_comments.py:837:1: D102 Missing docstring in public method
# tests/test_comments.py:851:80: E501 line too long (80 > 79 characters)
# tests/test_comment_manipulation.py:1:1: D100 Missing docstring in public module
# tests/test_comment_manipulation.py:8:1: D103 Missing docstring in public function
# tests/test_comment_manipulation.py:12:1: D103 Missing docstring in public function
# tests/test_comment_manipulation.py:16:1: D103 Missing docstring in public function
# tests/test_comment_manipulation.py:22:1: D101 Missing docstring in public class
# tests/test_comment_manipulation.py:25:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:39:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:53:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:67:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:83:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:104:1: D205 1 blank line required between summary line and description
# tests/test_comment_manipulation.py:104:1: D400 First line should end with a period
# tests/test_comment_manipulation.py:104:1: D403 First word of the first line should be properly capitalized
# tests/test_comment_manipulation.py:131:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:147:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:165:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:183:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:201:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:220:1: D205 1 blank line required between summary line and description
# tests/test_comment_manipulation.py:220:1: D400 First line should end with a period
# tests/test_comment_manipulation.py:220:1: D403 First word of the first line should be properly capitalized
# tests/test_comment_manipulation.py:242:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:256:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:272:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:289:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:304:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:322:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:339:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:357:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:376:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:396:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:416:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:436:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:465:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:465:10: N802 function name 'Xtest_map_set_comment_before_and_after_non_first_key_01' should be lowercase
# tests/test_comment_manipulation.py:479:80: E501 line too long (83 > 79 characters)
# tests/test_comment_manipulation.py:497:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:526:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:526:10: N802 function name 'Xtest_map_set_comment_before_and_after_non_first_key_02' should be lowercase
# tests/test_comment_manipulation.py:537:80: E501 line too long (94 > 79 characters)
# tests/test_comment_manipulation.py:540:80: E501 line too long (83 > 79 characters)
# tests/test_comment_manipulation.py:558:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:569:80: E501 line too long (94 > 79 characters)
# tests/test_contextmanager.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_contextmanager.py:3:1: D400 First line should end with a period
# tests/test_contextmanager.py:34:1: D103 Missing docstring in public function
# tests/test_contextmanager.py:40:1: D101 Missing docstring in public class
# tests/test_contextmanager.py:41:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:47:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:51:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:55:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:60:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:68:1: D101 Missing docstring in public class
# tests/test_contextmanager.py:69:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:78:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:106:1: D102 Missing docstring in public method
# tests/test_copy.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_copy.py:3:1: D400 First line should end with a period
# tests/test_copy.py:14:1: D101 Missing docstring in public class
# tests/test_copy.py:15:1: D102 Missing docstring in public method
# tests/test_copy.py:27:1: D102 Missing docstring in public method
# tests/test_copy.py:49:1: D102 Missing docstring in public method
# tests/test_copy.py:73:1: D101 Missing docstring in public class
# tests/test_copy.py:74:1: D102 Missing docstring in public method
# tests/test_copy.py:96:1: D102 Missing docstring in public method
# tests/test_cyaml.py:1:1: D100 Missing docstring in public module
# tests/test_cyaml.py:15:1: D103 Missing docstring in public function
# tests/test_cyaml.py:30:1: D103 Missing docstring in public function
# tests/test_cyaml.py:45:80: E501 line too long (82 > 79 characters)
# tests/test_cyaml.py:47:1: D103 Missing docstring in public function
# tests/test_cyaml.py:64:80: E501 line too long (82 > 79 characters)
# tests/test_cyaml.py:66:1: D103 Missing docstring in public function
# tests/test_datetime.py:3:1: D205 1 blank line required between summary line and description
# tests/test_datetime.py:3:1: D400 First line should end with a period
# tests/test_datetime.py:28:1: D101 Missing docstring in public class
# tests/test_datetime.py:29:1: D102 Missing docstring in public method
# tests/test_datetime.py:38:1: D102 Missing docstring in public method
# tests/test_datetime.py:47:1: D102 Missing docstring in public method
# tests/test_datetime.py:64:1: D102 Missing docstring in public method
# tests/test_datetime.py:73:1: D102 Missing docstring in public method
# tests/test_datetime.py:82:1: D102 Missing docstring in public method
# tests/test_datetime.py:90:1: D102 Missing docstring in public method
# tests/test_datetime.py:99:1: D102 Missing docstring in public method
# tests/test_datetime.py:99:10: N802 function name 'test_explicit_T' should be lowercase
# tests/test_datetime.py:108:1: D102 Missing docstring in public method
# tests/test_datetime.py:117:1: D102 Missing docstring in public method
# tests/test_datetime.py:117:10: N802 function name 'test_no_T_multi_space' should be lowercase
# tests/test_datetime.py:126:1: D102 Missing docstring in public method
# tests/test_datetime.py:131:1: D102 Missing docstring in public method
# tests/test_datetime.py:136:1: D102 Missing docstring in public method
# tests/test_datetime.py:141:1: D102 Missing docstring in public method
# tests/test_datetime.py:149:1: D102 Missing docstring in public method
# tests/test_deprecation.py:1:1: D100 Missing docstring in public module
# tests/test_deprecation.py:9:1: D103 Missing docstring in public function
# tests/test_documents.py:1:1: D100 Missing docstring in public module
# tests/test_documents.py:8:1: D101 Missing docstring in public class
# tests/test_documents.py:9:1: D102 Missing docstring in public method
# tests/test_documents.py:18:1: D102 Missing docstring in public method
# tests/test_documents.py:32:1: D102 Missing docstring in public method
# tests/test_documents.py:43:1: D102 Missing docstring in public method
# tests/test_documents.py:52:1: D102 Missing docstring in public method
# tests/test_documents.py:63:1: D102 Missing docstring in public method
# tests/test_fail.py:1:1: D100 Missing docstring in public module
# tests/test_fail.py:6:80: E501 line too long (84 > 79 characters)
# tests/test_fail.py:14:1: D101 Missing docstring in public class
# tests/test_fail.py:16:1: D102 Missing docstring in public method
# tests/test_fail.py:29:1: D102 Missing docstring in public method
# tests/test_fail.py:52:1: D102 Missing docstring in public method
# tests/test_fail.py:59:1: D102 Missing docstring in public method
# tests/test_fail.py:74:1: D101 Missing docstring in public class
# tests/test_fail.py:76:1: D102 Missing docstring in public method
# tests/test_fail.py:100:1: D102 Missing docstring in public method
# tests/test_fail.py:146:1: D102 Missing docstring in public method
# tests/test_fail.py:146:10: N802 function name 'Xtest_indent_top_level_no_fail' should be lowercase
# tests/test_fail.py:154:1: D101 Missing docstring in public class
# tests/test_fail.py:156:1: D102 Missing docstring in public method
# tests/test_fail.py:164:1: D102 Missing docstring in public method
# tests/test_fail.py:179:1: D101 Missing docstring in public class
# tests/test_fail.py:180:1: D102 Missing docstring in public method
# tests/test_fail.py:186:1: D102 Missing docstring in public method
# tests/test_fail.py:193:1: D101 Missing docstring in public class
# tests/test_fail.py:194:1: D102 Missing docstring in public method
# tests/test_fail.py:200:1: D102 Missing docstring in public method
# tests/test_fail.py:209:1: D102 Missing docstring in public method
# tests/test_fail.py:216:80: E501 line too long (95 > 79 characters)
# tests/test_fail.py:222:1: D102 Missing docstring in public method
# tests/test_float.py:1:1: D100 Missing docstring in public module
# tests/test_float.py:10:1: D101 Missing docstring in public class
# tests/test_float.py:11:1: D102 Missing docstring in public method
# tests/test_float.py:40:1: D102 Missing docstring in public method
# tests/test_float.py:56:1: D102 Missing docstring in public method
# tests/test_float.py:56:10: N802 function name 'Xtest_round_trip_non_exp_trailing_dot' should be lowercase
# tests/test_float.py:61:1: D102 Missing docstring in public method
# tests/test_float.py:72:1: D101 Missing docstring in public class
# tests/test_float.py:73:1: D102 Missing docstring in public method
# tests/test_flowsequencekey.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_flowsequencekey.py:3:1: D400 First line should end with a period
# tests/test_flowsequencekey.py:13:1: D101 Missing docstring in public class
# tests/test_flowsequencekey.py:14:1: D102 Missing docstring in public method
# tests/test_flowsequencekey.py:25:80: E501 line too long (82 > 79 characters)
# tests/test_indentation.py:1:1: D100 Missing docstring in public module
# tests/test_indentation.py:5:80: E501 line too long (80 > 79 characters)
# tests/test_indentation.py:8:1: D103 Missing docstring in public function
# tests/test_indentation.py:14:1: D101 Missing docstring in public class
# tests/test_indentation.py:15:1: D102 Missing docstring in public method
# tests/test_indentation.py:20:1: D102 Missing docstring in public method
# tests/test_indentation.py:28:1: D102 Missing docstring in public method
# tests/test_indentation.py:38:1: D102 Missing docstring in public method
# tests/test_indentation.py:48:1: D102 Missing docstring in public method
# tests/test_indentation.py:65:1: D102 Missing docstring in public method
# tests/test_indentation.py:74:1: D102 Missing docstring in public method
# tests/test_indentation.py:83:1: D102 Missing docstring in public method
# tests/test_indentation.py:90:1: D102 Missing docstring in public method
# tests/test_indentation.py:100:1: D102 Missing docstring in public method
# tests/test_indentation.py:110:1: D102 Missing docstring in public method
# tests/test_indentation.py:120:1: D102 Missing docstring in public method
# tests/test_indentation.py:120:10: N802 function name 'Xtest_set_indent_3_block_list_indent_2' should be lowercase
# tests/test_indentation.py:134:1: D102 Missing docstring in public method
# tests/test_indentation.py:144:1: D102 Missing docstring in public method
# tests/test_indentation.py:144:10: N802 function name 'Xtest_set_indent_2_block_list_indent_2' should be lowercase
# tests/test_indentation.py:159:1: D102 Missing docstring in public method
# tests/test_indentation.py:170:1: D102 Missing docstring in public method
# tests/test_indentation.py:180:1: D102 Missing docstring in public method
# tests/test_indentation.py:194:1: D101 Missing docstring in public class
# tests/test_indentation.py:195:1: D102 Missing docstring in public method
# tests/test_indentation.py:202:80: E501 line too long (95 > 79 characters)
# tests/test_indentation.py:209:80: E501 line too long (88 > 79 characters)
# tests/test_indentation.py:210:80: E501 line too long (83 > 79 characters)
# tests/test_indentation.py:213:80: E501 line too long (91 > 79 characters)
# tests/test_indentation.py:217:1: D103 Missing docstring in public function
# tests/test_indentation.py:224:1: D101 Missing docstring in public class
# tests/test_indentation.py:225:1: D102 Missing docstring in public method
# tests/test_indentation.py:232:1: D102 Missing docstring in public method
# tests/test_indentation.py:239:1: D102 Missing docstring in public method
# tests/test_indentation.py:248:1: D102 Missing docstring in public method
# tests/test_indentation.py:248:10: N802 function name 'test_guess_3None' should be lowercase
# tests/test_indentation.py:256:1: D101 Missing docstring in public class
# tests/test_indentation.py:259:1: D102 Missing docstring in public method
# tests/test_indentation.py:271:1: D102 Missing docstring in public method
# tests/test_indentation.py:282:1: D102 Missing docstring in public method
# tests/test_indentation.py:293:1: D102 Missing docstring in public method
# tests/test_indentation.py:303:1: D102 Missing docstring in public method
# tests/test_indentation.py:315:1: D102 Missing docstring in public method
# tests/test_int.py:1:1: D100 Missing docstring in public module
# tests/test_int.py:10:1: D101 Missing docstring in public class
# tests/test_int.py:11:1: D102 Missing docstring in public method
# tests/test_issues.py:1:1: D100 Missing docstring in public module
# tests/test_issues.py:17:1: D101 Missing docstring in public class
# tests/test_issues.py:18:1: D102 Missing docstring in public method
# tests/test_issues.py:30:80: E501 line too long (89 > 79 characters)
# tests/test_issues.py:32:1: D102 Missing docstring in public method
# tests/test_issues.py:65:80: E501 line too long (85 > 79 characters)
# tests/test_issues.py:75:1: D102 Missing docstring in public method
# tests/test_issues.py:79:1: D102 Missing docstring in public method
# tests/test_issues.py:89:1: D102 Missing docstring in public method
# tests/test_issues.py:106:1: D102 Missing docstring in public method
# tests/test_issues.py:130:1: D102 Missing docstring in public method
# tests/test_issues.py:140:1: D102 Missing docstring in public method
# tests/test_issues.py:150:1: D102 Missing docstring in public method
# tests/test_issues.py:166:1: D102 Missing docstring in public method
# tests/test_issues.py:170:1: D102 Missing docstring in public method
# tests/test_issues.py:178:1: D102 Missing docstring in public method
# tests/test_issues.py:193:1: D102 Missing docstring in public method
# tests/test_issues.py:243:1: D102 Missing docstring in public method
# tests/test_issues.py:255:1: D102 Missing docstring in public method
# tests/test_issues.py:261:1: D102 Missing docstring in public method
# tests/test_issues.py:268:1: D102 Missing docstring in public method
# tests/test_issues.py:283:1: D102 Missing docstring in public method
# tests/test_issues.py:289:1: D102 Missing docstring in public method
# tests/test_issues.py:314:1: D102 Missing docstring in public method
# tests/test_issues.py:339:1: D102 Missing docstring in public method
# tests/test_issues.py:364:1: D102 Missing docstring in public method
# tests/test_issues.py:389:1: D102 Missing docstring in public method
# tests/test_issues.py:398:1: D102 Missing docstring in public method
# tests/test_issues.py:404:1: D102 Missing docstring in public method
# tests/test_issues.py:414:1: D102 Missing docstring in public method
# tests/test_issues.py:422:1: D102 Missing docstring in public method
# tests/test_issues.py:430:1: D102 Missing docstring in public method
# tests/test_issues.py:447:1: D102 Missing docstring in public method
# tests/test_issues.py:455:1: D102 Missing docstring in public method
# tests/test_issues.py:487:1: D102 Missing docstring in public method
# tests/test_issues.py:507:1: D102 Missing docstring in public method
# tests/test_issues.py:513:1: D102 Missing docstring in public method
# tests/test_issues.py:531:1: D102 Missing docstring in public method
# tests/test_issues.py:548:1: D102 Missing docstring in public method
# tests/test_issues.py:560:1: D102 Missing docstring in public method
# tests/test_issues.py:579:1: D102 Missing docstring in public method
# tests/test_issues.py:590:1: D102 Missing docstring in public method
# tests/test_issues.py:593:80: E501 line too long (88 > 79 characters)
# tests/test_issues.py:599:1: D102 Missing docstring in public method
# tests/test_issues.py:614:80: E501 line too long (89 > 79 characters)
# tests/test_issues.py:617:1: D102 Missing docstring in public method
# tests/test_issues.py:635:1: D102 Missing docstring in public method
# tests/test_issues.py:651:1: D102 Missing docstring in public method
# tests/test_issues.py:682:1: D102 Missing docstring in public method
# tests/test_issues.py:713:1: D102 Missing docstring in public method
# tests/test_issues.py:749:1: D102 Missing docstring in public method
# tests/test_issues.py:785:80: E501 line too long (95 > 79 characters)
# tests/test_issues.py:786:1: D102 Missing docstring in public method
# tests/test_issues.py:787:80: E501 line too long (81 > 79 characters)
# tests/test_issues.py:788:80: E501 line too long (80 > 79 characters)
# tests/test_issues.py:811:1: D102 Missing docstring in public method
# tests/test_issues.py:822:1: D102 Missing docstring in public method
# tests/test_issues.py:836:1: D102 Missing docstring in public method
# tests/test_issues.py:846:1: D102 Missing docstring in public method
# tests/test_issues.py:855:1: D102 Missing docstring in public method
# tests/test_json_numbers.py:1:1: D100 Missing docstring in public module
# tests/test_json_numbers.py:8:1: D103 Missing docstring in public function
# tests/test_json_numbers.py:22:1: D101 Missing docstring in public class
# tests/test_json_numbers.py:29:1: D102 Missing docstring in public method
# tests/test_json_numbers.py:46:1: D102 Missing docstring in public method
# tests/test_line_col.py:1:1: D100 Missing docstring in public module
# tests/test_line_col.py:8:1: D103 Missing docstring in public function
# tests/test_line_col.py:12:1: D101 Missing docstring in public class
# tests/test_line_col.py:13:1: D102 Missing docstring in public method
# tests/test_line_col.py:23:1: D102 Missing docstring in public method
# tests/test_line_col.py:33:1: D102 Missing docstring in public method
# tests/test_line_col.py:43:1: D102 Missing docstring in public method
# tests/test_line_col.py:55:1: D102 Missing docstring in public method
# tests/test_line_col.py:69:1: D102 Missing docstring in public method
# tests/test_line_col.py:81:1: D102 Missing docstring in public method
# tests/test_literal.py:1:1: D100 Missing docstring in public module
# tests/test_literal.py:12:80: E501 line too long (85 > 79 characters)
# tests/test_literal.py:14:80: E501 line too long (92 > 79 characters)
# tests/test_literal.py:16:80: E501 line too long (87 > 79 characters)
# tests/test_literal.py:29:1: D101 Missing docstring in public class
# tests/test_literal.py:30:1: D102 Missing docstring in public method
# tests/test_literal.py:41:1: D102 Missing docstring in public method
# tests/test_literal.py:52:1: D102 Missing docstring in public method
# tests/test_literal.py:64:1: D102 Missing docstring in public method
# tests/test_literal.py:79:1: D102 Missing docstring in public method
# tests/test_literal.py:94:1: D102 Missing docstring in public method
# tests/test_literal.py:105:1: D102 Missing docstring in public method
# tests/test_literal.py:116:1: D102 Missing docstring in public method
# tests/test_literal.py:128:1: D102 Missing docstring in public method
# tests/test_literal.py:139:1: D102 Missing docstring in public method
# tests/test_literal.py:150:1: D102 Missing docstring in public method
# tests/test_literal.py:161:1: D102 Missing docstring in public method
# tests/test_literal.py:172:1: D102 Missing docstring in public method
# tests/test_literal.py:186:1: D102 Missing docstring in public method
# tests/test_literal.py:197:1: D102 Missing docstring in public method
# tests/test_literal.py:208:1: D102 Missing docstring in public method
# tests/test_literal.py:220:1: D102 Missing docstring in public method
# tests/test_literal.py:234:1: D101 Missing docstring in public class
# tests/test_literal.py:234:8: N801 class name 'Test_RoundTripLiteral' should use CapWords convention
# tests/test_literal.py:235:1: D102 Missing docstring in public method
# tests/test_literal.py:247:1: D102 Missing docstring in public method
# tests/test_literal.py:260:1: D102 Missing docstring in public method
# tests/test_literal.py:273:1: D102 Missing docstring in public method
# tests/test_literal.py:286:1: D102 Missing docstring in public method
# tests/test_literal.py:299:1: D102 Missing docstring in public method
# tests/test_literal.py:314:1: D102 Missing docstring in public method
# tests/test_literal.py:326:1: D102 Missing docstring in public method
# tests/test_none.py:1:1: D100 Missing docstring in public module
# tests/test_none.py:7:1: D101 Missing docstring in public class
# tests/test_none.py:8:1: D102 Missing docstring in public method
# tests/test_none.py:15:1: D102 Missing docstring in public method
# tests/test_none.py:22:1: D102 Missing docstring in public method
# tests/test_none.py:29:1: D102 Missing docstring in public method
# tests/test_none.py:36:1: D102 Missing docstring in public method
# tests/test_numpy.py:1:1: D100 Missing docstring in public module
# tests/test_numpy.py:9:1: D103 Missing docstring in public function
# tests/test_numpy.py:9:6: N802 function name 'Xtest_numpy' should be lowercase
# tests/test_program_config.py:1:1: D100 Missing docstring in public module
# tests/test_program_config.py:9:1: D101 Missing docstring in public class
# tests/test_program_config.py:10:1: D102 Missing docstring in public method
# tests/test_program_config.py:23:1: D102 Missing docstring in public method
# tests/test_program_config.py:42:1: D102 Missing docstring in public method
# tests/test_spec_examples.py:1:1: D100 Missing docstring in public module
# tests/test_spec_examples.py:7:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:17:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:27:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:43:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:59:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:70:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:84:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:100:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:118:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:135:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:152:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:168:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:184:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:195:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:208:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:222:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:236:80: E501 line too long (82 > 79 characters)
# tests/test_spec_examples.py:238:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:253:80: E501 line too long (93 > 79 characters)
# tests/test_spec_examples.py:254:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:267:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:278:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:289:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:289:6: N802 function name 'Xtest_example_2_X' should be lowercase
# tests/test_string.py:3:1: D205 1 blank line required between summary line and description
# tests/test_string.py:3:1: D400 First line should end with a period
# tests/test_string.py:23:1: D101 Missing docstring in public class
# tests/test_string.py:24:1: D102 Missing docstring in public method
# tests/test_string.py:29:1: D102 Missing docstring in public method
# tests/test_string.py:35:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:37:1: D102 Missing docstring in public method
# tests/test_string.py:46:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:48:1: D102 Missing docstring in public method
# tests/test_string.py:58:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:60:1: D102 Missing docstring in public method
# tests/test_string.py:73:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:75:1: D102 Missing docstring in public method
# tests/test_string.py:87:1: D102 Missing docstring in public method
# tests/test_string.py:96:1: D102 Missing docstring in public method
# tests/test_string.py:105:1: D102 Missing docstring in public method
# tests/test_string.py:116:1: D101 Missing docstring in public class
# tests/test_string.py:117:1: D102 Missing docstring in public method
# tests/test_string.py:123:1: D102 Missing docstring in public method
# tests/test_string.py:129:1: D102 Missing docstring in public method
# tests/test_string.py:140:1: D400 First line should end with a period
# tests/test_string.py:142:1: D102 Missing docstring in public method
# tests/test_string.py:162:1: D102 Missing docstring in public method
# tests/test_string.py:170:80: E501 line too long (80 > 79 characters)
# tests/test_string.py:174:1: D101 Missing docstring in public class
# tests/test_string.py:175:1: D102 Missing docstring in public method
# tests/test_string.py:191:1: D102 Missing docstring in public method
# tests/test_string.py:195:10: N813 camelcase 'DoubleQuotedScalarString' imported as lowercase 'dq'
# tests/test_string.py:196:10: N813 camelcase 'SingleQuotedScalarString' imported as lowercase 'sq'
# tests/test_tag.py:1:1: D100 Missing docstring in public module
# tests/test_tag.py:8:1: D103 Missing docstring in public function
# tests/test_tag.py:22:80: E501 line too long (86 > 79 characters)
# tests/test_tag.py:23:80: E501 line too long (83 > 79 characters)
# tests/test_tag.py:26:1: D101 Missing docstring in public class
# tests/test_tag.py:27:1: D102 Missing docstring in public method
# tests/test_tag.py:35:1: D102 Missing docstring in public method
# tests/test_tag.py:43:1: D102 Missing docstring in public method
# tests/test_tag.py:51:1: D102 Missing docstring in public method
# tests/test_tag.py:51:10: N802 function name 'test_Y1' should be lowercase
# tests/test_tag.py:59:1: D102 Missing docstring in public method
# tests/test_tag.py:59:10: N802 function name 'test_Y2' should be lowercase
# tests/test_tag.py:68:1: D101 Missing docstring in public class
# tests/test_tag.py:69:1: D102 Missing docstring in public method
# tests/test_tag.py:69:10: N802 function name 'test_X1' should be lowercase
# tests/test_tag.py:79:1: D102 Missing docstring in public method
# tests/test_tag.py:79:10: N802 function name 'test_X_pre_tag_comment' should be lowercase
# tests/test_tag.py:91:1: D102 Missing docstring in public method
# tests/test_tag.py:91:10: N802 function name 'test_X_post_tag_comment' should be lowercase
# tests/test_tag.py:101:1: D102 Missing docstring in public method
# tests/test_tag.py:112:1: D101 Missing docstring in public class
# tests/test_tag.py:113:1: D102 Missing docstring in public method
# tests/test_tag.py:119:1: D101 Missing docstring in public class
# tests/test_tag.py:120:1: D102 Missing docstring in public method
# tests/test_tag.py:125:1: D102 Missing docstring in public method
# tests/test_tag.py:130:1: D102 Missing docstring in public method
# tests/test_tag.py:138:1: D102 Missing docstring in public method
# tests/test_version.py:1:1: D100 Missing docstring in public module
# tests/test_version.py:8:1: D103 Missing docstring in public function
# tests/test_version.py:16:1: D101 Missing docstring in public class
# tests/test_version.py:17:1: D102 Missing docstring in public method
# tests/test_version.py:41:1: D102 Missing docstring in public method
# tests/test_version.py:65:1: D102 Missing docstring in public method
# tests/test_version.py:89:1: D102 Missing docstring in public method
# tests/test_version.py:115:1: D101 Missing docstring in public class
# tests/test_version.py:117:1: D102 Missing docstring in public method
# tests/test_version.py:128:80: E501 line too long (88 > 79 characters)
# tests/test_version.py:134:1: D102 Missing docstring in public method
# tests/test_version.py:144:80: E501 line too long (88 > 79 characters)
# tests/test_version.py:149:80: E501 line too long (88 > 79 characters)
# tests/test_version.py:151:1: D102 Missing docstring in public method
# tests/test_version.py:161:80: E501 line too long (84 > 79 characters)
# tests/test_version.py:163:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_yamlfile.py:3:1: D400 First line should end with a period
# tests/test_yamlfile.py:15:1: D101 Missing docstring in public class
# tests/test_yamlfile.py:16:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:22:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:35:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:44:80: E501 line too long (86 > 79 characters)
# tests/test_yamlfile.py:45:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:59:80: E501 line too long (84 > 79 characters)
# tests/test_yamlfile.py:62:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:75:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:75:10: N802 function name 'test_CommentedSet' should be lowercase
# tests/test_yamlfile.py:87:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:105:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:114:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:122:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:133:80: E501 line too long (93 > 79 characters)
# tests/test_yamlfile.py:135:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:157:80: E501 line too long (93 > 79 characters)
# tests/test_yamlfile.py:160:1: D210 No whitespaces allowed surrounding docstring text
# ...
# tests/test_z_data.py:113:1: D102 Missing docstring in public method
# tests/test_z_data.py:123:1: D102 Missing docstring in public method
# tests/test_z_data.py:128:1: D102 Missing docstring in public method
# tests/test_z_data.py:138:1: D102 Missing docstring in public method
# tests/test_z_data.py:157:1: D102 Missing docstring in public method
# tests/test_z_data.py:162:80: E501 line too long (82 > 79 characters)
# tests/test_z_data.py:165:1: D205 1 blank line required between summary line and description
# tests/test_z_data.py:165:1: D208 Docstring is over-indented
# tests/test_z_data.py:165:1: D400 First line should end with a period
# tests/test_z_data.py:165:1: D401 First line should be in imperative mood; try rephrasing
# tests/test_z_data.py:165:1: D403 First word of the first line should be properly capitalized
# tests/test_z_data.py:183:1: D102 Missing docstring in public method
# tests/test_z_data.py:230:80: E501 line too long (94 > 79 characters)
# tests/test_z_data.py:242:1: D205 1 blank line required between summary line and description
# tests/test_z_data.py:242:1: D403 First word of the first line should be properly capitalized
# tests/test_z_olddata.py:1:1: D100 Missing docstring in public module
# tests/test_z_olddata.py:15:1: D103 Missing docstring in public function
# tests/test_z_olddata.py:29:1: D103 Missing docstring in public function
# tests/lib/canonical.py:1:1: D100 Missing docstring in public module
# tests/lib/canonical.py:8:1: D101 Missing docstring in public class
# tests/lib/canonical.py:12:1: D101 Missing docstring in public class
# tests/lib/canonical.py:13:1: D107 Missing docstring in __init__
# tests/lib/canonical.py:24:1: D102 Missing docstring in public method
# tests/lib/canonical.py:35:1: D102 Missing docstring in public method
# tests/lib/canonical.py:41:1: D102 Missing docstring in public method
# tests/lib/canonical.py:49:1: D102 Missing docstring in public method
# tests/lib/canonical.py:53:1: D102 Missing docstring in public method
# tests/lib/canonical.py:63:52: E203 whitespace before ':'
# tests/lib/canonical.py:68:80: E501 line too long (82 > 79 characters)
# tests/lib/canonical.py:71:80: E501 line too long (81 > 79 characters)
# tests/lib/canonical.py:74:80: E501 line too long (80 > 79 characters)
# tests/lib/canonical.py:99:1: D102 Missing docstring in public method
# tests/lib/canonical.py:101:33: E203 whitespace before ':'
# tests/lib/canonical.py:101:80: E501 line too long (86 > 79 characters)
# tests/lib/canonical.py:109:1: D102 Missing docstring in public method
# tests/lib/canonical.py:111:14: N806 variable 'TokenClass' in function should be lowercase
# tests/lib/canonical.py:113:14: N806 variable 'TokenClass' in function should be lowercase
# tests/lib/canonical.py:118:32: E203 whitespace before ':'
# tests/lib/canonical.py:121:1: D102 Missing docstring in public method
# tests/lib/canonical.py:126:32: E203 whitespace before ':'
# tests/lib/canonical.py:158:1: D102 Missing docstring in public method
# tests/lib/canonical.py:166:46: E203 whitespace before ':'
# tests/lib/canonical.py:174:52: E203 whitespace before ':'
# tests/lib/canonical.py:183:46: E203 whitespace before ':'
# tests/lib/canonical.py:194:38: E203 whitespace before ':'
# tests/lib/canonical.py:198:1: D102 Missing docstring in public method
# tests/lib/canonical.py:212:1: D101 Missing docstring in public class
# tests/lib/canonical.py:213:1: D107 Missing docstring in __init__
# tests/lib/canonical.py:217:1: D102 Missing docstring in public method
# tests/lib/canonical.py:221:1: D102 Missing docstring in public method
# tests/lib/canonical.py:225:80: E501 line too long (92 > 79 characters)
# tests/lib/canonical.py:228:80: E501 line too long (89 > 79 characters)
# tests/lib/canonical.py:233:1: D102 Missing docstring in public method
# tests/lib/canonical.py:243:1: D102 Missing docstring in public method
# tests/lib/canonical.py:245:80: E501 line too long (90 > 79 characters)
# tests/lib/canonical.py:256:80: E501 line too long (87 > 79 characters)
# tests/lib/canonical.py:260:80: E501 line too long (91 > 79 characters)
# tests/lib/canonical.py:263:80: E501 line too long (90 > 79 characters)
# tests/lib/canonical.py:267:80: E501 line too long (82 > 79 characters)
# tests/lib/canonical.py:271:1: D102 Missing docstring in public method
# tests/lib/canonical.py:283:1: D102 Missing docstring in public method
# tests/lib/canonical.py:295:1: D102 Missing docstring in public method
# tests/lib/canonical.py:301:1: D102 Missing docstring in public method
# tests/lib/canonical.py:305:1: D102 Missing docstring in public method
# tests/lib/canonical.py:310:1: D102 Missing docstring in public method
# tests/lib/canonical.py:321:1: D102 Missing docstring in public method
# tests/lib/canonical.py:327:1: D101 Missing docstring in public class
# tests/lib/canonical.py:327:80: E501 line too long (90 > 79 characters)
# tests/lib/canonical.py:328:1: D107 Missing docstring in __init__
# tests/lib/canonical.py:341:1: D103 Missing docstring in public function
# tests/lib/canonical.py:350:1: D103 Missing docstring in public function
# tests/lib/canonical.py:357:1: D103 Missing docstring in public function
# tests/lib/canonical.py:364:1: D103 Missing docstring in public function
# tests/lib/canonical.py:371:1: D103 Missing docstring in public function
# tests/lib/canonical.py:378:1: D103 Missing docstring in public function
# tests/lib/test_all.py:1:1: D100 Missing docstring in public module
# tests/lib/test_all.py:7:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:1:1: D100 Missing docstring in public module
# tests/lib/test_appliance.py:16:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:25:80: E501 line too long (84 > 79 characters)
# tests/lib/test_appliance.py:30:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:44:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:69:80: E501 line too long (83 > 79 characters)
# tests/lib/test_appliance.py:105:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:132:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:176:1: D103 Missing docstring in public function
# tests/lib/test_build.py:1:1: D100 Missing docstring in public module
# tests/lib/test_build.py:9:80: E501 line too long (80 > 79 characters)
# tests/lib/test_build_ext.py:1:1: D100 Missing docstring in public module
# tests/lib/test_build_ext.py:10:80: E501 line too long (80 > 79 characters)
# tests/lib/test_canonical.py:1:1: D100 Missing docstring in public module
# tests/lib/test_canonical.py:7:1: D103 Missing docstring in public function
# tests/lib/test_canonical.py:20:1: D103 Missing docstring in public function
# tests/lib/test_canonical.py:33:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:1:1: D100 Missing docstring in public module
# tests/lib/test_constructor.py:14:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:21:80: E501 line too long (274 > 79 characters)
# tests/lib/test_constructor.py:37:80: E501 line too long (87 > 79 characters)
# tests/lib/test_constructor.py:96:80: E501 line too long (87 > 79 characters)
# tests/lib/test_constructor.py:120:80: E501 line too long (87 > 79 characters)
# tests/lib/test_constructor.py:133:20: F821 undefined name 'cmp'
# tests/lib/test_constructor.py:139:80: E501 line too long (84 > 79 characters)
# tests/lib/test_constructor.py:152:20: F821 undefined name 'cmp'
# tests/lib/test_constructor.py:158:80: E501 line too long (84 > 79 characters)
# tests/lib/test_constructor.py:269:1: D101 Missing docstring in public class
# tests/lib/test_constructor.py:269:12: N801 class name 'ordereddict' should use CapWords convention
# tests/lib/test_constructor.py:296:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:320:80: E501 line too long (89 > 79 characters)
# tests/lib/test_constructor.py:332:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:336:12: F821 undefined name 'YAML'
# tests/lib/test_emitter.py:1:1: D100 Missing docstring in public module
# tests/lib/test_emitter.py:21:1: D103 Missing docstring in public function
# tests/lib/test_emitter.py:35:1: D103 Missing docstring in public function
# tests/lib/test_emitter.py:50:1: D103 Missing docstring in public function
# tests/lib/test_emitter.py:60:80: E501 line too long (93 > 79 characters)
# tests/lib/test_emitter.py:64:80: E501 line too long (90 > 79 characters)
# tests/lib/test_emitter.py:68:80: E501 line too long (90 > 79 characters)
# tests/lib/test_emitter.py:85:1: D101 Missing docstring in public class
# tests/lib/test_emitter.py:86:1: D102 Missing docstring in public method
# tests/lib/test_emitter.py:99:80: E501 line too long (84 > 79 characters)
# tests/lib/test_emitter.py:117:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:1:1: D100 Missing docstring in public module
# tests/lib/test_errors.py:5:1: E402 module level import not at top of file
# tests/lib/test_errors.py:6:1: E402 module level import not at top of file
# tests/lib/test_errors.py:11:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:26:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:41:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:56:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:72:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:1:1: D100 Missing docstring in public module
# tests/lib/test_input_output.py:9:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:9:1: E302 expected 2 blank lines, found 1
# tests/lib/test_input_output.py:35:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:66:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:75:80: E501 line too long (84 > 79 characters)
# tests/lib/test_input_output.py:77:80: E501 line too long (84 > 79 characters)
# tests/lib/test_input_output.py:85:80: E501 line too long (85 > 79 characters)
# tests/lib/test_input_output.py:94:80: E501 line too long (88 > 79 characters)
# tests/lib/test_input_output.py:120:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:152:1: D103 Missing docstring in public function
# tests/lib/test_mark.py:1:1: D100 Missing docstring in public module
# tests/lib/test_mark.py:5:1: D103 Missing docstring in public function
# tests/lib/test_mark.py:19:80: E501 line too long (80 > 79 characters)
# tests/lib/test_reader.py:1:1: D100 Missing docstring in public module
# tests/lib/test_reader.py:20:1: D103 Missing docstring in public function
# tests/lib/test_recursive.py:1:1: D100 Missing docstring in public module
# tests/lib/test_recursive.py:5:1: D101 Missing docstring in public class
# tests/lib/test_recursive.py:6:1: D107 Missing docstring in __init__
# tests/lib/test_recursive.py:10:1: D105 Missing docstring in magic method
# tests/lib/test_recursive.py:12:80: E501 line too long (87 > 79 characters)
# tests/lib/test_recursive.py:17:1: D101 Missing docstring in public class
# tests/lib/test_recursive.py:18:1: D105 Missing docstring in magic method
# tests/lib/test_recursive.py:21:1: D105 Missing docstring in magic method
# tests/lib/test_recursive.py:25:1: D103 Missing docstring in public function
# tests/lib/test_representer.py:1:1: D100 Missing docstring in public module
# tests/lib/test_representer.py:7:1: D103 Missing docstring in public function
# tests/lib/test_resolver.py:1:1: D100 Missing docstring in public module
# tests/lib/test_resolver.py:6:1: D103 Missing docstring in public function
# tests/lib/test_resolver.py:39:80: E501 line too long (85 > 79 characters)
# tests/lib/test_resolver.py:41:80: E501 line too long (83 > 79 characters)
# tests/lib/test_resolver.py:43:80: E501 line too long (93 > 79 characters)
# tests/lib/test_resolver.py:70:1: D103 Missing docstring in public function
# tests/lib/test_resolver.py:89:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:1:1: D100 Missing docstring in public module
# tests/lib/test_structure.py:38:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:75:80: E501 line too long (91 > 79 characters)
# tests/lib/test_structure.py:76:80: E501 line too long (89 > 79 characters)
# tests/lib/test_structure.py:82:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:102:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:137:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:174:80: E501 line too long (81 > 79 characters)
# tests/lib/test_structure.py:183:80: E501 line too long (84 > 79 characters)
# tests/lib/test_structure.py:196:80: E501 line too long (82 > 79 characters)
# tests/lib/test_structure.py:199:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:204:12: F821 undefined name 'YAML'
# tests/lib/test_tokens.py:1:1: D100 Missing docstring in public module
# tests/lib/test_tokens.py:46:1: D103 Missing docstring in public function
# tests/lib/test_tokens.py:54:80: E501 line too long (101 > 79 characters)
# tests/lib/test_tokens.py:68:1: D103 Missing docstring in public function
# tests/lib/test_yaml.py:1:1: D100 Missing docstring in public module
# tests/lib/test_yaml_ext.py:1:1: D100 Missing docstring in public module
# tests/lib/test_yaml_ext.py:18:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:18:23: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:25:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:25:24: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:32:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:32:26: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:39:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:39:30: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:46:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:46:23: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:53:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:53:27: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:60:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:67:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:74:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:74:36: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:81:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:81:34: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:88:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:88:44: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:95:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:95:34: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:102:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:102:43: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:109:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:116:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:168:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:172:80: E501 line too long (92 > 79 characters)
# tests/lib/test_yaml_ext.py:208:80: E501 line too long (92 > 79 characters)
# tests/lib/test_yaml_ext.py:219:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:267:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:331:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:342:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:356:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:365:80: E501 line too long (84 > 79 characters)
# setup.py:0:1: E902 FileNotFoundError: [Errno 2] No such file or directory: 'setup.py'

# %%
# flake8 pydantic ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 pydantic
# Out:
# pydantic:0:1: E902 FileNotFoundError: [Errno 2] No such file or directory: 'pydantic'

# %%
# flake8 tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 tests
# Out:
# tests/roundtrip.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/roundtrip.py:3:1: D400 First line should end with a period
# tests/roundtrip.py:14:1: D103 Missing docstring in public function
# tests/roundtrip.py:23:50: E203 whitespace before ':'
# tests/roundtrip.py:27:1: D103 Missing docstring in public function
# tests/roundtrip.py:37:1: D103 Missing docstring in public function
# tests/roundtrip.py:47:1: D103 Missing docstring in public function
# tests/roundtrip.py:80:1: D103 Missing docstring in public function
# tests/roundtrip.py:113:1: D103 Missing docstring in public function
# tests/roundtrip.py:142:1: D205 1 blank line required between summary line and description
# tests/roundtrip.py:142:1: D400 First line should end with a period
# tests/roundtrip.py:203:1: D205 1 blank line required between summary line and description
# tests/roundtrip.py:203:1: D400 First line should end with a period
# tests/roundtrip.py:236:1: D103 Missing docstring in public function
# tests/roundtrip.py:236:6: N802 function name 'YAML' should be lowercase
# tests/roundtrip.py:240:1: D400 First line should end with a period
# tests/roundtrip.py:314:80: E501 line too long (87 > 79 characters)
# tests/roundtrip.py:315:1: D205 1 blank line required between summary line and description
# tests/roundtrip.py:315:1: D400 First line should end with a period
# tests/roundtrip.py:315:1: D403 First word of the first line should be properly capitalized
# tests/roundtrip.py:316:80: E501 line too long (89 > 79 characters)
# tests/roundtrip.py:335:80: E501 line too long (90 > 79 characters)
# tests/roundtrip.py:345:80: E501 line too long (85 > 79 characters)
# tests/test_add_xxx.py:1:1: D100 Missing docstring in public module
# tests/test_add_xxx.py:10:1: D101 Missing docstring in public class
# tests/test_add_xxx.py:11:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:14:1: D105 Missing docstring in magic method
# tests/test_add_xxx.py:18:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:24:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:28:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:37:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:41:80: E501 line too long (85 > 79 characters)
# tests/test_add_xxx.py:46:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:58:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:71:1: D101 Missing docstring in public class
# tests/test_add_xxx.py:72:1: D107 Missing docstring in __init__
# tests/test_add_xxx.py:76:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:79:1: D105 Missing docstring in magic method
# tests/test_add_xxx.py:82:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:86:1: D101 Missing docstring in public class
# tests/test_add_xxx.py:90:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:101:1: D102 Missing docstring in public method
# tests/test_add_xxx.py:102:80: E501 line too long (80 > 79 characters)
# tests/test_add_xxx.py:105:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:118:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:122:80: E501 line too long (82 > 79 characters)
# tests/test_add_xxx.py:140:1: D103 Missing docstring in public function
# tests/test_add_xxx.py:157:80: E501 line too long (82 > 79 characters)
# tests/test_add_xxx.py:161:80: E501 line too long (86 > 79 characters)
# tests/test_anchor.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_anchor.py:3:1: D400 First line should end with a period
# tests/test_anchor.py:14:1: D103 Missing docstring in public function
# tests/test_anchor.py:18:1: D103 Missing docstring in public function
# tests/test_anchor.py:22:1: D101 Missing docstring in public class
# tests/test_anchor.py:23:1: D102 Missing docstring in public method
# tests/test_anchor.py:44:1: D400 First line should end with a period
# tests/test_anchor.py:44:1: D403 First word of the first line should be properly capitalized
# tests/test_anchor.py:62:1: D102 Missing docstring in public method
# tests/test_anchor.py:83:1: D102 Missing docstring in public method
# tests/test_anchor.py:109:80: E501 line too long (93 > 79 characters)
# tests/test_anchor.py:111:1: D102 Missing docstring in public method
# tests/test_anchor.py:123:1: D102 Missing docstring in public method
# tests/test_anchor.py:168:1: D102 Missing docstring in public method
# tests/test_anchor.py:184:1: D102 Missing docstring in public method
# tests/test_anchor.py:199:1: D102 Missing docstring in public method
# tests/test_anchor.py:203:1: D102 Missing docstring in public method
# tests/test_anchor.py:215:1: D102 Missing docstring in public method
# tests/test_anchor.py:228:1: D102 Missing docstring in public method
# tests/test_anchor.py:249:1: D102 Missing docstring in public method
# tests/test_anchor.py:263:1: D102 Missing docstring in public method
# tests/test_anchor.py:286:80: E501 line too long (80 > 79 characters)
# tests/test_anchor.py:288:1: D102 Missing docstring in public method
# tests/test_anchor.py:312:80: E501 line too long (80 > 79 characters)
# tests/test_anchor.py:315:1: D101 Missing docstring in public class
# tests/test_anchor.py:334:1: D102 Missing docstring in public method
# tests/test_anchor.py:345:1: D102 Missing docstring in public method
# tests/test_anchor.py:356:1: D102 Missing docstring in public method
# tests/test_anchor.py:367:1: D102 Missing docstring in public method
# tests/test_anchor.py:378:1: D102 Missing docstring in public method
# tests/test_anchor.py:398:1: D102 Missing docstring in public method
# tests/test_anchor.py:436:1: D102 Missing docstring in public method
# tests/test_anchor.py:443:1: D102 Missing docstring in public method
# tests/test_anchor.py:463:1: D101 Missing docstring in public class
# tests/test_anchor.py:464:1: D102 Missing docstring in public method
# tests/test_anchor.py:467:80: E501 line too long (88 > 79 characters)
# tests/test_anchor.py:489:1: D102 Missing docstring in public method
# tests/test_anchor.py:513:1: D101 Missing docstring in public class
# tests/test_anchor.py:514:1: D102 Missing docstring in public method
# tests/test_anchor.py:525:1: D102 Missing docstring in public method
# tests/test_anchor.py:534:1: D102 Missing docstring in public method
# tests/test_anchor.py:540:80: E501 line too long (80 > 79 characters)
# tests/test_api_change.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_api_change.py:3:1: D400 First line should end with a period
# tests/test_api_change.py:13:1: D101 Missing docstring in public class
# tests/test_api_change.py:14:1: D102 Missing docstring in public method
# tests/test_api_change.py:22:1: D102 Missing docstring in public method
# tests/test_api_change.py:30:1: D102 Missing docstring in public method
# tests/test_api_change.py:38:1: D102 Missing docstring in public method
# tests/test_api_change.py:47:1: D102 Missing docstring in public method
# tests/test_api_change.py:56:1: D101 Missing docstring in public class
# tests/test_api_change.py:57:1: D102 Missing docstring in public method
# tests/test_api_change.py:68:1: D102 Missing docstring in public method
# tests/test_api_change.py:80:1: D102 Missing docstring in public method
# tests/test_api_change.py:90:1: D102 Missing docstring in public method
# tests/test_api_change.py:101:1: D102 Missing docstring in public method
# tests/test_api_change.py:115:1: D102 Missing docstring in public method
# tests/test_api_change.py:127:1: D101 Missing docstring in public class
# tests/test_api_change.py:128:1: D102 Missing docstring in public method
# tests/test_api_change.py:136:1: D102 Missing docstring in public method
# tests/test_api_change.py:152:1: D101 Missing docstring in public class
# tests/test_api_change.py:154:1: D400 First line should end with a period
# tests/test_api_change.py:154:1: D403 First word of the first line should be properly capitalized
# tests/test_api_change.py:154:80: E501 line too long (82 > 79 characters)
# tests/test_api_change.py:171:1: D101 Missing docstring in public class
# tests/test_api_change.py:172:1: D102 Missing docstring in public method
# tests/test_api_change.py:190:1: D101 Missing docstring in public class
# tests/test_api_change.py:191:80: E501 line too long (92 > 79 characters)
# tests/test_api_change.py:193:1: D102 Missing docstring in public method
# tests/test_api_change.py:200:80: E501 line too long (85 > 79 characters)
# tests/test_api_change.py:202:1: D102 Missing docstring in public method
# tests/test_api_change.py:213:1: D101 Missing docstring in public class
# tests/test_api_change.py:214:1: D102 Missing docstring in public method
# tests/test_api_change.py:228:1: D101 Missing docstring in public class
# tests/test_api_change.py:230:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:1:1: D100 Missing docstring in public module
# tests/test_a_dedent.py:6:1: D101 Missing docstring in public class
# tests/test_a_dedent.py:7:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:16:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:25:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:33:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:38:1: D102 Missing docstring in public method
# tests/test_a_dedent.py:43:1: D102 Missing docstring in public method
# tests/test_class_register.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_class_register.py:3:1: D400 First line should end with a period
# tests/test_class_register.py:10:1: D101 Missing docstring in public class
# tests/test_class_register.py:11:1: D107 Missing docstring in __init__
# tests/test_class_register.py:16:1: D101 Missing docstring in public class
# tests/test_class_register.py:19:1: D107 Missing docstring in __init__
# tests/test_class_register.py:24:1: D102 Missing docstring in public method
# tests/test_class_register.py:25:80: E501 line too long (94 > 79 characters)
# tests/test_class_register.py:28:1: D102 Missing docstring in public method
# tests/test_class_register.py:32:1: D101 Missing docstring in public class
# tests/test_class_register.py:33:1: D102 Missing docstring in public method
# tests/test_class_register.py:44:1: D102 Missing docstring in public method
# tests/test_class_register.py:54:1: D102 Missing docstring in public method
# tests/test_class_register.py:64:1: D102 Missing docstring in public method
# tests/test_class_register.py:73:1: D102 Missing docstring in public method
# tests/test_class_register.py:82:1: D102 Missing docstring in public method
# tests/test_class_register.py:92:1: D101 Missing docstring in public class
# tests/test_class_register.py:93:1: D102 Missing docstring in public method
# tests/test_class_register.py:112:1: D102 Missing docstring in public method
# tests/test_collections.py:3:1: D400 First line should end with a period
# tests/test_collections.py:4:80: E501 line too long (90 > 79 characters)
# tests/test_collections.py:16:1: D101 Missing docstring in public class
# tests/test_collections.py:17:1: D102 Missing docstring in public method
# tests/test_comments.py:3:1: D205 1 blank line required between summary line and description
# tests/test_comments.py:3:1: D400 First line should end with a period
# tests/test_comments.py:19:1: D101 Missing docstring in public class
# tests/test_comments.py:21:1: D205 1 blank line required between summary line and description
# tests/test_comments.py:21:1: D209 Multi-line docstring closing quotes should be on a separate line
# tests/test_comments.py:21:1: D301 Use r""" if any backslashes in a docstring
# tests/test_comments.py:21:1: D400 First line should end with a period
# tests/test_comments.py:21:1: D403 First word of the first line should be properly capitalized
# tests/test_comments.py:29:1: D102 Missing docstring in public method
# tests/test_comments.py:37:1: D102 Missing docstring in public method
# tests/test_comments.py:49:1: D102 Missing docstring in public method
# tests/test_comments.py:57:1: D102 Missing docstring in public method
# tests/test_comments.py:65:1: D102 Missing docstring in public method
# tests/test_comments.py:76:1: D102 Missing docstring in public method
# tests/test_comments.py:90:1: D102 Missing docstring in public method
# tests/test_comments.py:101:1: D102 Missing docstring in public method
# tests/test_comments.py:112:1: D102 Missing docstring in public method
# tests/test_comments.py:123:1: D102 Missing docstring in public method
# tests/test_comments.py:136:1: D102 Missing docstring in public method
# tests/test_comments.py:148:1: D102 Missing docstring in public method
# tests/test_comments.py:159:1: D102 Missing docstring in public method
# tests/test_comments.py:167:1: D102 Missing docstring in public method
# tests/test_comments.py:175:1: D102 Missing docstring in public method
# tests/test_comments.py:184:1: D102 Missing docstring in public method
# tests/test_comments.py:197:1: D102 Missing docstring in public method
# tests/test_comments.py:214:1: D102 Missing docstring in public method
# tests/test_comments.py:225:1: D102 Missing docstring in public method
# tests/test_comments.py:234:1: D102 Missing docstring in public method
# tests/test_comments.py:244:1: D102 Missing docstring in public method
# tests/test_comments.py:266:1: D102 Missing docstring in public method
# tests/test_comments.py:281:1: D102 Missing docstring in public method
# tests/test_comments.py:296:1: D102 Missing docstring in public method
# tests/test_comments.py:313:1: D205 1 blank line required between summary line and description
# tests/test_comments.py:313:1: D209 Multi-line docstring closing quotes should be on a separate line
# tests/test_comments.py:313:1: D400 First line should end with a period
# tests/test_comments.py:317:1: D102 Missing docstring in public method
# tests/test_comments.py:330:1: D102 Missing docstring in public method
# tests/test_comments.py:347:1: D102 Missing docstring in public method
# tests/test_comments.py:364:1: D102 Missing docstring in public method
# tests/test_comments.py:381:1: D102 Missing docstring in public method
# tests/test_comments.py:397:1: D102 Missing docstring in public method
# tests/test_comments.py:413:1: D102 Missing docstring in public method
# tests/test_comments.py:429:1: D102 Missing docstring in public method
# tests/test_comments.py:447:1: D101 Missing docstring in public class
# tests/test_comments.py:449:1: D102 Missing docstring in public method
# tests/test_comments.py:456:1: D102 Missing docstring in public method
# tests/test_comments.py:468:1: D102 Missing docstring in public method
# tests/test_comments.py:480:1: D102 Missing docstring in public method
# tests/test_comments.py:494:1: D101 Missing docstring in public class
# tests/test_comments.py:495:1: D102 Missing docstring in public method
# tests/test_comments.py:511:1: D102 Missing docstring in public method
# tests/test_comments.py:522:1: D102 Missing docstring in public method
# tests/test_comments.py:535:1: D101 Missing docstring in public class
# tests/test_comments.py:537:1: D102 Missing docstring in public method
# tests/test_comments.py:552:1: D102 Missing docstring in public method
# tests/test_comments.py:568:1: D102 Missing docstring in public method
# tests/test_comments.py:584:1: D102 Missing docstring in public method
# tests/test_comments.py:592:1: D102 Missing docstring in public method
# tests/test_comments.py:601:1: D102 Missing docstring in public method
# tests/test_comments.py:613:1: D102 Missing docstring in public method
# tests/test_comments.py:624:1: D102 Missing docstring in public method
# tests/test_comments.py:635:1: D102 Missing docstring in public method
# tests/test_comments.py:648:1: D102 Missing docstring in public method
# tests/test_comments.py:658:1: D102 Missing docstring in public method
# tests/test_comments.py:667:1: D102 Missing docstring in public method
# tests/test_comments.py:675:1: D102 Missing docstring in public method
# tests/test_comments.py:682:1: D102 Missing docstring in public method
# tests/test_comments.py:690:1: D102 Missing docstring in public method
# tests/test_comments.py:703:1: D101 Missing docstring in public class
# tests/test_comments.py:705:1: D102 Missing docstring in public method
# tests/test_comments.py:724:1: D101 Missing docstring in public class
# tests/test_comments.py:725:1: D102 Missing docstring in public method
# tests/test_comments.py:733:1: D102 Missing docstring in public method
# tests/test_comments.py:741:1: D102 Missing docstring in public method
# tests/test_comments.py:747:1: D102 Missing docstring in public method
# tests/test_comments.py:755:1: D102 Missing docstring in public method
# tests/test_comments.py:764:1: D102 Missing docstring in public method
# tests/test_comments.py:771:1: D102 Missing docstring in public method
# tests/test_comments.py:779:1: D102 Missing docstring in public method
# tests/test_comments.py:786:1: D102 Missing docstring in public method
# tests/test_comments.py:794:1: D102 Missing docstring in public method
# tests/test_comments.py:801:1: D102 Missing docstring in public method
# tests/test_comments.py:816:1: D102 Missing docstring in public method
# tests/test_comments.py:835:1: D101 Missing docstring in public class
# tests/test_comments.py:837:1: D102 Missing docstring in public method
# tests/test_comments.py:851:80: E501 line too long (80 > 79 characters)
# tests/test_comment_manipulation.py:1:1: D100 Missing docstring in public module
# tests/test_comment_manipulation.py:8:1: D103 Missing docstring in public function
# tests/test_comment_manipulation.py:12:1: D103 Missing docstring in public function
# tests/test_comment_manipulation.py:16:1: D103 Missing docstring in public function
# tests/test_comment_manipulation.py:22:1: D101 Missing docstring in public class
# tests/test_comment_manipulation.py:25:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:39:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:53:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:67:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:83:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:104:1: D205 1 blank line required between summary line and description
# tests/test_comment_manipulation.py:104:1: D400 First line should end with a period
# tests/test_comment_manipulation.py:104:1: D403 First word of the first line should be properly capitalized
# tests/test_comment_manipulation.py:131:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:147:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:165:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:183:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:201:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:220:1: D205 1 blank line required between summary line and description
# tests/test_comment_manipulation.py:220:1: D400 First line should end with a period
# tests/test_comment_manipulation.py:220:1: D403 First word of the first line should be properly capitalized
# tests/test_comment_manipulation.py:242:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:256:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:272:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:289:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:304:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:322:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:339:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:357:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:376:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:396:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:416:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:436:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:465:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:465:10: N802 function name 'Xtest_map_set_comment_before_and_after_non_first_key_01' should be lowercase
# tests/test_comment_manipulation.py:479:80: E501 line too long (83 > 79 characters)
# tests/test_comment_manipulation.py:497:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:526:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:526:10: N802 function name 'Xtest_map_set_comment_before_and_after_non_first_key_02' should be lowercase
# tests/test_comment_manipulation.py:537:80: E501 line too long (94 > 79 characters)
# tests/test_comment_manipulation.py:540:80: E501 line too long (83 > 79 characters)
# tests/test_comment_manipulation.py:558:1: D102 Missing docstring in public method
# tests/test_comment_manipulation.py:569:80: E501 line too long (94 > 79 characters)
# tests/test_contextmanager.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_contextmanager.py:3:1: D400 First line should end with a period
# tests/test_contextmanager.py:34:1: D103 Missing docstring in public function
# tests/test_contextmanager.py:40:1: D101 Missing docstring in public class
# tests/test_contextmanager.py:41:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:47:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:51:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:55:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:60:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:68:1: D101 Missing docstring in public class
# tests/test_contextmanager.py:69:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:78:1: D102 Missing docstring in public method
# tests/test_contextmanager.py:106:1: D102 Missing docstring in public method
# tests/test_copy.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_copy.py:3:1: D400 First line should end with a period
# tests/test_copy.py:14:1: D101 Missing docstring in public class
# tests/test_copy.py:15:1: D102 Missing docstring in public method
# tests/test_copy.py:27:1: D102 Missing docstring in public method
# tests/test_copy.py:49:1: D102 Missing docstring in public method
# tests/test_copy.py:73:1: D101 Missing docstring in public class
# tests/test_copy.py:74:1: D102 Missing docstring in public method
# tests/test_copy.py:96:1: D102 Missing docstring in public method
# tests/test_cyaml.py:1:1: D100 Missing docstring in public module
# tests/test_cyaml.py:15:1: D103 Missing docstring in public function
# tests/test_cyaml.py:30:1: D103 Missing docstring in public function
# tests/test_cyaml.py:45:80: E501 line too long (82 > 79 characters)
# tests/test_cyaml.py:47:1: D103 Missing docstring in public function
# tests/test_cyaml.py:64:80: E501 line too long (82 > 79 characters)
# tests/test_cyaml.py:66:1: D103 Missing docstring in public function
# tests/test_datetime.py:3:1: D205 1 blank line required between summary line and description
# tests/test_datetime.py:3:1: D400 First line should end with a period
# tests/test_datetime.py:28:1: D101 Missing docstring in public class
# tests/test_datetime.py:29:1: D102 Missing docstring in public method
# tests/test_datetime.py:38:1: D102 Missing docstring in public method
# tests/test_datetime.py:47:1: D102 Missing docstring in public method
# tests/test_datetime.py:64:1: D102 Missing docstring in public method
# tests/test_datetime.py:73:1: D102 Missing docstring in public method
# tests/test_datetime.py:82:1: D102 Missing docstring in public method
# tests/test_datetime.py:90:1: D102 Missing docstring in public method
# tests/test_datetime.py:99:1: D102 Missing docstring in public method
# tests/test_datetime.py:99:10: N802 function name 'test_explicit_T' should be lowercase
# tests/test_datetime.py:108:1: D102 Missing docstring in public method
# tests/test_datetime.py:117:1: D102 Missing docstring in public method
# tests/test_datetime.py:117:10: N802 function name 'test_no_T_multi_space' should be lowercase
# tests/test_datetime.py:126:1: D102 Missing docstring in public method
# tests/test_datetime.py:131:1: D102 Missing docstring in public method
# tests/test_datetime.py:136:1: D102 Missing docstring in public method
# tests/test_datetime.py:141:1: D102 Missing docstring in public method
# tests/test_datetime.py:149:1: D102 Missing docstring in public method
# tests/test_deprecation.py:1:1: D100 Missing docstring in public module
# tests/test_deprecation.py:9:1: D103 Missing docstring in public function
# tests/test_documents.py:1:1: D100 Missing docstring in public module
# tests/test_documents.py:8:1: D101 Missing docstring in public class
# tests/test_documents.py:9:1: D102 Missing docstring in public method
# tests/test_documents.py:18:1: D102 Missing docstring in public method
# tests/test_documents.py:32:1: D102 Missing docstring in public method
# tests/test_documents.py:43:1: D102 Missing docstring in public method
# tests/test_documents.py:52:1: D102 Missing docstring in public method
# tests/test_documents.py:63:1: D102 Missing docstring in public method
# tests/test_fail.py:1:1: D100 Missing docstring in public module
# tests/test_fail.py:6:80: E501 line too long (84 > 79 characters)
# tests/test_fail.py:14:1: D101 Missing docstring in public class
# tests/test_fail.py:16:1: D102 Missing docstring in public method
# tests/test_fail.py:29:1: D102 Missing docstring in public method
# tests/test_fail.py:52:1: D102 Missing docstring in public method
# tests/test_fail.py:59:1: D102 Missing docstring in public method
# tests/test_fail.py:74:1: D101 Missing docstring in public class
# tests/test_fail.py:76:1: D102 Missing docstring in public method
# tests/test_fail.py:100:1: D102 Missing docstring in public method
# tests/test_fail.py:146:1: D102 Missing docstring in public method
# tests/test_fail.py:146:10: N802 function name 'Xtest_indent_top_level_no_fail' should be lowercase
# tests/test_fail.py:154:1: D101 Missing docstring in public class
# tests/test_fail.py:156:1: D102 Missing docstring in public method
# tests/test_fail.py:164:1: D102 Missing docstring in public method
# tests/test_fail.py:179:1: D101 Missing docstring in public class
# tests/test_fail.py:180:1: D102 Missing docstring in public method
# tests/test_fail.py:186:1: D102 Missing docstring in public method
# tests/test_fail.py:193:1: D101 Missing docstring in public class
# tests/test_fail.py:194:1: D102 Missing docstring in public method
# tests/test_fail.py:200:1: D102 Missing docstring in public method
# tests/test_fail.py:209:1: D102 Missing docstring in public method
# tests/test_fail.py:216:80: E501 line too long (95 > 79 characters)
# tests/test_fail.py:222:1: D102 Missing docstring in public method
# tests/test_float.py:1:1: D100 Missing docstring in public module
# tests/test_float.py:10:1: D101 Missing docstring in public class
# tests/test_float.py:11:1: D102 Missing docstring in public method
# tests/test_float.py:40:1: D102 Missing docstring in public method
# tests/test_float.py:56:1: D102 Missing docstring in public method
# tests/test_float.py:56:10: N802 function name 'Xtest_round_trip_non_exp_trailing_dot' should be lowercase
# tests/test_float.py:61:1: D102 Missing docstring in public method
# tests/test_float.py:72:1: D101 Missing docstring in public class
# tests/test_float.py:73:1: D102 Missing docstring in public method
# tests/test_flowsequencekey.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_flowsequencekey.py:3:1: D400 First line should end with a period
# tests/test_flowsequencekey.py:13:1: D101 Missing docstring in public class
# tests/test_flowsequencekey.py:14:1: D102 Missing docstring in public method
# tests/test_flowsequencekey.py:25:80: E501 line too long (82 > 79 characters)
# tests/test_indentation.py:1:1: D100 Missing docstring in public module
# tests/test_indentation.py:5:80: E501 line too long (80 > 79 characters)
# tests/test_indentation.py:8:1: D103 Missing docstring in public function
# tests/test_indentation.py:14:1: D101 Missing docstring in public class
# tests/test_indentation.py:15:1: D102 Missing docstring in public method
# tests/test_indentation.py:20:1: D102 Missing docstring in public method
# tests/test_indentation.py:28:1: D102 Missing docstring in public method
# tests/test_indentation.py:38:1: D102 Missing docstring in public method
# tests/test_indentation.py:48:1: D102 Missing docstring in public method
# tests/test_indentation.py:65:1: D102 Missing docstring in public method
# tests/test_indentation.py:74:1: D102 Missing docstring in public method
# tests/test_indentation.py:83:1: D102 Missing docstring in public method
# tests/test_indentation.py:90:1: D102 Missing docstring in public method
# tests/test_indentation.py:100:1: D102 Missing docstring in public method
# tests/test_indentation.py:110:1: D102 Missing docstring in public method
# tests/test_indentation.py:120:1: D102 Missing docstring in public method
# tests/test_indentation.py:120:10: N802 function name 'Xtest_set_indent_3_block_list_indent_2' should be lowercase
# tests/test_indentation.py:134:1: D102 Missing docstring in public method
# tests/test_indentation.py:144:1: D102 Missing docstring in public method
# tests/test_indentation.py:144:10: N802 function name 'Xtest_set_indent_2_block_list_indent_2' should be lowercase
# tests/test_indentation.py:159:1: D102 Missing docstring in public method
# tests/test_indentation.py:170:1: D102 Missing docstring in public method
# tests/test_indentation.py:180:1: D102 Missing docstring in public method
# tests/test_indentation.py:194:1: D101 Missing docstring in public class
# tests/test_indentation.py:195:1: D102 Missing docstring in public method
# tests/test_indentation.py:202:80: E501 line too long (95 > 79 characters)
# tests/test_indentation.py:209:80: E501 line too long (88 > 79 characters)
# tests/test_indentation.py:210:80: E501 line too long (83 > 79 characters)
# tests/test_indentation.py:213:80: E501 line too long (91 > 79 characters)
# tests/test_indentation.py:217:1: D103 Missing docstring in public function
# tests/test_indentation.py:224:1: D101 Missing docstring in public class
# tests/test_indentation.py:225:1: D102 Missing docstring in public method
# tests/test_indentation.py:232:1: D102 Missing docstring in public method
# tests/test_indentation.py:239:1: D102 Missing docstring in public method
# tests/test_indentation.py:248:1: D102 Missing docstring in public method
# tests/test_indentation.py:248:10: N802 function name 'test_guess_3None' should be lowercase
# tests/test_indentation.py:256:1: D101 Missing docstring in public class
# tests/test_indentation.py:259:1: D102 Missing docstring in public method
# tests/test_indentation.py:271:1: D102 Missing docstring in public method
# tests/test_indentation.py:282:1: D102 Missing docstring in public method
# tests/test_indentation.py:293:1: D102 Missing docstring in public method
# tests/test_indentation.py:303:1: D102 Missing docstring in public method
# tests/test_indentation.py:315:1: D102 Missing docstring in public method
# tests/test_int.py:1:1: D100 Missing docstring in public module
# tests/test_int.py:10:1: D101 Missing docstring in public class
# tests/test_int.py:11:1: D102 Missing docstring in public method
# tests/test_issues.py:1:1: D100 Missing docstring in public module
# tests/test_issues.py:17:1: D101 Missing docstring in public class
# tests/test_issues.py:18:1: D102 Missing docstring in public method
# tests/test_issues.py:30:80: E501 line too long (89 > 79 characters)
# tests/test_issues.py:32:1: D102 Missing docstring in public method
# tests/test_issues.py:65:80: E501 line too long (85 > 79 characters)
# tests/test_issues.py:75:1: D102 Missing docstring in public method
# tests/test_issues.py:79:1: D102 Missing docstring in public method
# tests/test_issues.py:89:1: D102 Missing docstring in public method
# tests/test_issues.py:106:1: D102 Missing docstring in public method
# tests/test_issues.py:130:1: D102 Missing docstring in public method
# tests/test_issues.py:140:1: D102 Missing docstring in public method
# tests/test_issues.py:150:1: D102 Missing docstring in public method
# tests/test_issues.py:166:1: D102 Missing docstring in public method
# tests/test_issues.py:170:1: D102 Missing docstring in public method
# tests/test_issues.py:178:1: D102 Missing docstring in public method
# tests/test_issues.py:193:1: D102 Missing docstring in public method
# tests/test_issues.py:243:1: D102 Missing docstring in public method
# tests/test_issues.py:255:1: D102 Missing docstring in public method
# tests/test_issues.py:261:1: D102 Missing docstring in public method
# tests/test_issues.py:268:1: D102 Missing docstring in public method
# tests/test_issues.py:283:1: D102 Missing docstring in public method
# tests/test_issues.py:289:1: D102 Missing docstring in public method
# tests/test_issues.py:314:1: D102 Missing docstring in public method
# tests/test_issues.py:339:1: D102 Missing docstring in public method
# tests/test_issues.py:364:1: D102 Missing docstring in public method
# tests/test_issues.py:389:1: D102 Missing docstring in public method
# tests/test_issues.py:398:1: D102 Missing docstring in public method
# tests/test_issues.py:404:1: D102 Missing docstring in public method
# tests/test_issues.py:414:1: D102 Missing docstring in public method
# tests/test_issues.py:422:1: D102 Missing docstring in public method
# tests/test_issues.py:430:1: D102 Missing docstring in public method
# tests/test_issues.py:447:1: D102 Missing docstring in public method
# tests/test_issues.py:455:1: D102 Missing docstring in public method
# tests/test_issues.py:487:1: D102 Missing docstring in public method
# tests/test_issues.py:507:1: D102 Missing docstring in public method
# tests/test_issues.py:513:1: D102 Missing docstring in public method
# tests/test_issues.py:531:1: D102 Missing docstring in public method
# tests/test_issues.py:548:1: D102 Missing docstring in public method
# tests/test_issues.py:560:1: D102 Missing docstring in public method
# tests/test_issues.py:579:1: D102 Missing docstring in public method
# tests/test_issues.py:590:1: D102 Missing docstring in public method
# tests/test_issues.py:593:80: E501 line too long (88 > 79 characters)
# tests/test_issues.py:599:1: D102 Missing docstring in public method
# tests/test_issues.py:614:80: E501 line too long (89 > 79 characters)
# tests/test_issues.py:617:1: D102 Missing docstring in public method
# tests/test_issues.py:635:1: D102 Missing docstring in public method
# tests/test_issues.py:651:1: D102 Missing docstring in public method
# tests/test_issues.py:682:1: D102 Missing docstring in public method
# tests/test_issues.py:713:1: D102 Missing docstring in public method
# tests/test_issues.py:749:1: D102 Missing docstring in public method
# tests/test_issues.py:785:80: E501 line too long (95 > 79 characters)
# tests/test_issues.py:786:1: D102 Missing docstring in public method
# tests/test_issues.py:787:80: E501 line too long (81 > 79 characters)
# tests/test_issues.py:788:80: E501 line too long (80 > 79 characters)
# tests/test_issues.py:811:1: D102 Missing docstring in public method
# tests/test_issues.py:822:1: D102 Missing docstring in public method
# tests/test_issues.py:836:1: D102 Missing docstring in public method
# tests/test_issues.py:846:1: D102 Missing docstring in public method
# tests/test_issues.py:855:1: D102 Missing docstring in public method
# tests/test_json_numbers.py:1:1: D100 Missing docstring in public module
# tests/test_json_numbers.py:8:1: D103 Missing docstring in public function
# tests/test_json_numbers.py:22:1: D101 Missing docstring in public class
# tests/test_json_numbers.py:29:1: D102 Missing docstring in public method
# tests/test_json_numbers.py:46:1: D102 Missing docstring in public method
# tests/test_line_col.py:1:1: D100 Missing docstring in public module
# tests/test_line_col.py:8:1: D103 Missing docstring in public function
# tests/test_line_col.py:12:1: D101 Missing docstring in public class
# tests/test_line_col.py:13:1: D102 Missing docstring in public method
# tests/test_line_col.py:23:1: D102 Missing docstring in public method
# tests/test_line_col.py:33:1: D102 Missing docstring in public method
# tests/test_line_col.py:43:1: D102 Missing docstring in public method
# tests/test_line_col.py:55:1: D102 Missing docstring in public method
# tests/test_line_col.py:69:1: D102 Missing docstring in public method
# tests/test_line_col.py:81:1: D102 Missing docstring in public method
# tests/test_literal.py:1:1: D100 Missing docstring in public module
# tests/test_literal.py:12:80: E501 line too long (85 > 79 characters)
# tests/test_literal.py:14:80: E501 line too long (92 > 79 characters)
# tests/test_literal.py:16:80: E501 line too long (87 > 79 characters)
# tests/test_literal.py:29:1: D101 Missing docstring in public class
# tests/test_literal.py:30:1: D102 Missing docstring in public method
# tests/test_literal.py:41:1: D102 Missing docstring in public method
# tests/test_literal.py:52:1: D102 Missing docstring in public method
# tests/test_literal.py:64:1: D102 Missing docstring in public method
# tests/test_literal.py:79:1: D102 Missing docstring in public method
# tests/test_literal.py:94:1: D102 Missing docstring in public method
# tests/test_literal.py:105:1: D102 Missing docstring in public method
# tests/test_literal.py:116:1: D102 Missing docstring in public method
# tests/test_literal.py:128:1: D102 Missing docstring in public method
# tests/test_literal.py:139:1: D102 Missing docstring in public method
# tests/test_literal.py:150:1: D102 Missing docstring in public method
# tests/test_literal.py:161:1: D102 Missing docstring in public method
# tests/test_literal.py:172:1: D102 Missing docstring in public method
# tests/test_literal.py:186:1: D102 Missing docstring in public method
# tests/test_literal.py:197:1: D102 Missing docstring in public method
# tests/test_literal.py:208:1: D102 Missing docstring in public method
# tests/test_literal.py:220:1: D102 Missing docstring in public method
# tests/test_literal.py:234:1: D101 Missing docstring in public class
# tests/test_literal.py:234:8: N801 class name 'Test_RoundTripLiteral' should use CapWords convention
# tests/test_literal.py:235:1: D102 Missing docstring in public method
# tests/test_literal.py:247:1: D102 Missing docstring in public method
# tests/test_literal.py:260:1: D102 Missing docstring in public method
# tests/test_literal.py:273:1: D102 Missing docstring in public method
# tests/test_literal.py:286:1: D102 Missing docstring in public method
# tests/test_literal.py:299:1: D102 Missing docstring in public method
# tests/test_literal.py:314:1: D102 Missing docstring in public method
# tests/test_literal.py:326:1: D102 Missing docstring in public method
# tests/test_none.py:1:1: D100 Missing docstring in public module
# tests/test_none.py:7:1: D101 Missing docstring in public class
# tests/test_none.py:8:1: D102 Missing docstring in public method
# tests/test_none.py:15:1: D102 Missing docstring in public method
# tests/test_none.py:22:1: D102 Missing docstring in public method
# tests/test_none.py:29:1: D102 Missing docstring in public method
# tests/test_none.py:36:1: D102 Missing docstring in public method
# tests/test_numpy.py:1:1: D100 Missing docstring in public module
# tests/test_numpy.py:9:1: D103 Missing docstring in public function
# tests/test_numpy.py:9:6: N802 function name 'Xtest_numpy' should be lowercase
# tests/test_program_config.py:1:1: D100 Missing docstring in public module
# tests/test_program_config.py:9:1: D101 Missing docstring in public class
# tests/test_program_config.py:10:1: D102 Missing docstring in public method
# tests/test_program_config.py:23:1: D102 Missing docstring in public method
# tests/test_program_config.py:42:1: D102 Missing docstring in public method
# tests/test_spec_examples.py:1:1: D100 Missing docstring in public module
# tests/test_spec_examples.py:7:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:17:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:27:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:43:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:59:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:70:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:84:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:100:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:118:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:135:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:152:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:168:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:184:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:195:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:208:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:222:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:236:80: E501 line too long (82 > 79 characters)
# tests/test_spec_examples.py:238:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:253:80: E501 line too long (93 > 79 characters)
# tests/test_spec_examples.py:254:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:267:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:278:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:289:1: D103 Missing docstring in public function
# tests/test_spec_examples.py:289:6: N802 function name 'Xtest_example_2_X' should be lowercase
# tests/test_string.py:3:1: D205 1 blank line required between summary line and description
# tests/test_string.py:3:1: D400 First line should end with a period
# tests/test_string.py:23:1: D101 Missing docstring in public class
# tests/test_string.py:24:1: D102 Missing docstring in public method
# tests/test_string.py:29:1: D102 Missing docstring in public method
# tests/test_string.py:35:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:37:1: D102 Missing docstring in public method
# tests/test_string.py:46:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:48:1: D102 Missing docstring in public method
# tests/test_string.py:58:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:60:1: D102 Missing docstring in public method
# tests/test_string.py:73:80: E501 line too long (93 > 79 characters)
# tests/test_string.py:75:1: D102 Missing docstring in public method
# tests/test_string.py:87:1: D102 Missing docstring in public method
# tests/test_string.py:96:1: D102 Missing docstring in public method
# tests/test_string.py:105:1: D102 Missing docstring in public method
# tests/test_string.py:116:1: D101 Missing docstring in public class
# tests/test_string.py:117:1: D102 Missing docstring in public method
# tests/test_string.py:123:1: D102 Missing docstring in public method
# tests/test_string.py:129:1: D102 Missing docstring in public method
# tests/test_string.py:140:1: D400 First line should end with a period
# tests/test_string.py:142:1: D102 Missing docstring in public method
# tests/test_string.py:162:1: D102 Missing docstring in public method
# tests/test_string.py:170:80: E501 line too long (80 > 79 characters)
# tests/test_string.py:174:1: D101 Missing docstring in public class
# tests/test_string.py:175:1: D102 Missing docstring in public method
# tests/test_string.py:191:1: D102 Missing docstring in public method
# tests/test_string.py:195:10: N813 camelcase 'DoubleQuotedScalarString' imported as lowercase 'dq'
# tests/test_string.py:196:10: N813 camelcase 'SingleQuotedScalarString' imported as lowercase 'sq'
# tests/test_tag.py:1:1: D100 Missing docstring in public module
# tests/test_tag.py:8:1: D103 Missing docstring in public function
# tests/test_tag.py:22:80: E501 line too long (86 > 79 characters)
# tests/test_tag.py:23:80: E501 line too long (83 > 79 characters)
# tests/test_tag.py:26:1: D101 Missing docstring in public class
# tests/test_tag.py:27:1: D102 Missing docstring in public method
# tests/test_tag.py:35:1: D102 Missing docstring in public method
# tests/test_tag.py:43:1: D102 Missing docstring in public method
# tests/test_tag.py:51:1: D102 Missing docstring in public method
# tests/test_tag.py:51:10: N802 function name 'test_Y1' should be lowercase
# tests/test_tag.py:59:1: D102 Missing docstring in public method
# tests/test_tag.py:59:10: N802 function name 'test_Y2' should be lowercase
# tests/test_tag.py:68:1: D101 Missing docstring in public class
# tests/test_tag.py:69:1: D102 Missing docstring in public method
# tests/test_tag.py:69:10: N802 function name 'test_X1' should be lowercase
# tests/test_tag.py:79:1: D102 Missing docstring in public method
# tests/test_tag.py:79:10: N802 function name 'test_X_pre_tag_comment' should be lowercase
# tests/test_tag.py:91:1: D102 Missing docstring in public method
# tests/test_tag.py:91:10: N802 function name 'test_X_post_tag_comment' should be lowercase
# tests/test_tag.py:101:1: D102 Missing docstring in public method
# tests/test_tag.py:112:1: D101 Missing docstring in public class
# tests/test_tag.py:113:1: D102 Missing docstring in public method
# tests/test_tag.py:119:1: D101 Missing docstring in public class
# tests/test_tag.py:120:1: D102 Missing docstring in public method
# tests/test_tag.py:125:1: D102 Missing docstring in public method
# tests/test_tag.py:130:1: D102 Missing docstring in public method
# tests/test_tag.py:138:1: D102 Missing docstring in public method
# tests/test_version.py:1:1: D100 Missing docstring in public module
# tests/test_version.py:8:1: D103 Missing docstring in public function
# tests/test_version.py:16:1: D101 Missing docstring in public class
# tests/test_version.py:17:1: D102 Missing docstring in public method
# tests/test_version.py:41:1: D102 Missing docstring in public method
# tests/test_version.py:65:1: D102 Missing docstring in public method
# tests/test_version.py:89:1: D102 Missing docstring in public method
# tests/test_version.py:115:1: D101 Missing docstring in public class
# tests/test_version.py:117:1: D102 Missing docstring in public method
# tests/test_version.py:128:80: E501 line too long (88 > 79 characters)
# tests/test_version.py:134:1: D102 Missing docstring in public method
# tests/test_version.py:144:80: E501 line too long (88 > 79 characters)
# tests/test_version.py:149:80: E501 line too long (88 > 79 characters)
# tests/test_version.py:151:1: D102 Missing docstring in public method
# tests/test_version.py:161:80: E501 line too long (84 > 79 characters)
# tests/test_version.py:163:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:3:1: D200 One-line docstring should fit on one line with quotes
# tests/test_yamlfile.py:3:1: D400 First line should end with a period
# tests/test_yamlfile.py:15:1: D101 Missing docstring in public class
# tests/test_yamlfile.py:16:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:22:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:35:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:44:80: E501 line too long (86 > 79 characters)
# tests/test_yamlfile.py:45:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:59:80: E501 line too long (84 > 79 characters)
# tests/test_yamlfile.py:62:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:75:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:75:10: N802 function name 'test_CommentedSet' should be lowercase
# tests/test_yamlfile.py:87:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:105:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:114:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:122:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:133:80: E501 line too long (93 > 79 characters)
# tests/test_yamlfile.py:135:1: D102 Missing docstring in public method
# tests/test_yamlfile.py:157:80: E501 line too long (93 > 79 characters)
# tests/test_yamlfile.py:160:1: D210 No whitespaces allowed surrounding docstring text
# tests/test_yamlfile.py:160:1: D400 First line should end with a period
# ...
# tests/test_z_data.py:103:1: D101 Missing docstring in public class
# tests/test_z_data.py:104:1: D102 Missing docstring in public method
# tests/test_z_data.py:113:1: D102 Missing docstring in public method
# tests/test_z_data.py:123:1: D102 Missing docstring in public method
# tests/test_z_data.py:128:1: D102 Missing docstring in public method
# tests/test_z_data.py:138:1: D102 Missing docstring in public method
# tests/test_z_data.py:157:1: D102 Missing docstring in public method
# tests/test_z_data.py:162:80: E501 line too long (82 > 79 characters)
# tests/test_z_data.py:165:1: D205 1 blank line required between summary line and description
# tests/test_z_data.py:165:1: D208 Docstring is over-indented
# tests/test_z_data.py:165:1: D400 First line should end with a period
# tests/test_z_data.py:165:1: D401 First line should be in imperative mood; try rephrasing
# tests/test_z_data.py:165:1: D403 First word of the first line should be properly capitalized
# tests/test_z_data.py:183:1: D102 Missing docstring in public method
# tests/test_z_data.py:230:80: E501 line too long (94 > 79 characters)
# tests/test_z_data.py:242:1: D205 1 blank line required between summary line and description
# tests/test_z_data.py:242:1: D403 First word of the first line should be properly capitalized
# tests/test_z_olddata.py:1:1: D100 Missing docstring in public module
# tests/test_z_olddata.py:15:1: D103 Missing docstring in public function
# tests/test_z_olddata.py:29:1: D103 Missing docstring in public function
# tests/lib/canonical.py:1:1: D100 Missing docstring in public module
# tests/lib/canonical.py:8:1: D101 Missing docstring in public class
# tests/lib/canonical.py:12:1: D101 Missing docstring in public class
# tests/lib/canonical.py:13:1: D107 Missing docstring in __init__
# tests/lib/canonical.py:24:1: D102 Missing docstring in public method
# tests/lib/canonical.py:35:1: D102 Missing docstring in public method
# tests/lib/canonical.py:41:1: D102 Missing docstring in public method
# tests/lib/canonical.py:49:1: D102 Missing docstring in public method
# tests/lib/canonical.py:53:1: D102 Missing docstring in public method
# tests/lib/canonical.py:63:52: E203 whitespace before ':'
# tests/lib/canonical.py:68:80: E501 line too long (82 > 79 characters)
# tests/lib/canonical.py:71:80: E501 line too long (81 > 79 characters)
# tests/lib/canonical.py:74:80: E501 line too long (80 > 79 characters)
# tests/lib/canonical.py:99:1: D102 Missing docstring in public method
# tests/lib/canonical.py:101:33: E203 whitespace before ':'
# tests/lib/canonical.py:101:80: E501 line too long (86 > 79 characters)
# tests/lib/canonical.py:109:1: D102 Missing docstring in public method
# tests/lib/canonical.py:111:14: N806 variable 'TokenClass' in function should be lowercase
# tests/lib/canonical.py:113:14: N806 variable 'TokenClass' in function should be lowercase
# tests/lib/canonical.py:118:32: E203 whitespace before ':'
# tests/lib/canonical.py:121:1: D102 Missing docstring in public method
# tests/lib/canonical.py:126:32: E203 whitespace before ':'
# tests/lib/canonical.py:158:1: D102 Missing docstring in public method
# tests/lib/canonical.py:166:46: E203 whitespace before ':'
# tests/lib/canonical.py:174:52: E203 whitespace before ':'
# tests/lib/canonical.py:183:46: E203 whitespace before ':'
# tests/lib/canonical.py:194:38: E203 whitespace before ':'
# tests/lib/canonical.py:198:1: D102 Missing docstring in public method
# tests/lib/canonical.py:212:1: D101 Missing docstring in public class
# tests/lib/canonical.py:213:1: D107 Missing docstring in __init__
# tests/lib/canonical.py:217:1: D102 Missing docstring in public method
# tests/lib/canonical.py:221:1: D102 Missing docstring in public method
# tests/lib/canonical.py:225:80: E501 line too long (92 > 79 characters)
# tests/lib/canonical.py:228:80: E501 line too long (89 > 79 characters)
# tests/lib/canonical.py:233:1: D102 Missing docstring in public method
# tests/lib/canonical.py:243:1: D102 Missing docstring in public method
# tests/lib/canonical.py:245:80: E501 line too long (90 > 79 characters)
# tests/lib/canonical.py:256:80: E501 line too long (87 > 79 characters)
# tests/lib/canonical.py:260:80: E501 line too long (91 > 79 characters)
# tests/lib/canonical.py:263:80: E501 line too long (90 > 79 characters)
# tests/lib/canonical.py:267:80: E501 line too long (82 > 79 characters)
# tests/lib/canonical.py:271:1: D102 Missing docstring in public method
# tests/lib/canonical.py:283:1: D102 Missing docstring in public method
# tests/lib/canonical.py:295:1: D102 Missing docstring in public method
# tests/lib/canonical.py:301:1: D102 Missing docstring in public method
# tests/lib/canonical.py:305:1: D102 Missing docstring in public method
# tests/lib/canonical.py:310:1: D102 Missing docstring in public method
# tests/lib/canonical.py:321:1: D102 Missing docstring in public method
# tests/lib/canonical.py:327:1: D101 Missing docstring in public class
# tests/lib/canonical.py:327:80: E501 line too long (90 > 79 characters)
# tests/lib/canonical.py:328:1: D107 Missing docstring in __init__
# tests/lib/canonical.py:341:1: D103 Missing docstring in public function
# tests/lib/canonical.py:350:1: D103 Missing docstring in public function
# tests/lib/canonical.py:357:1: D103 Missing docstring in public function
# tests/lib/canonical.py:364:1: D103 Missing docstring in public function
# tests/lib/canonical.py:371:1: D103 Missing docstring in public function
# tests/lib/canonical.py:378:1: D103 Missing docstring in public function
# tests/lib/test_all.py:1:1: D100 Missing docstring in public module
# tests/lib/test_all.py:7:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:1:1: D100 Missing docstring in public module
# tests/lib/test_appliance.py:16:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:25:80: E501 line too long (84 > 79 characters)
# tests/lib/test_appliance.py:30:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:44:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:69:80: E501 line too long (83 > 79 characters)
# tests/lib/test_appliance.py:105:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:132:1: D103 Missing docstring in public function
# tests/lib/test_appliance.py:176:1: D103 Missing docstring in public function
# tests/lib/test_build.py:1:1: D100 Missing docstring in public module
# tests/lib/test_build.py:9:80: E501 line too long (80 > 79 characters)
# tests/lib/test_build_ext.py:1:1: D100 Missing docstring in public module
# tests/lib/test_build_ext.py:10:80: E501 line too long (80 > 79 characters)
# tests/lib/test_canonical.py:1:1: D100 Missing docstring in public module
# tests/lib/test_canonical.py:7:1: D103 Missing docstring in public function
# tests/lib/test_canonical.py:20:1: D103 Missing docstring in public function
# tests/lib/test_canonical.py:33:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:1:1: D100 Missing docstring in public module
# tests/lib/test_constructor.py:14:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:21:80: E501 line too long (274 > 79 characters)
# tests/lib/test_constructor.py:37:80: E501 line too long (87 > 79 characters)
# tests/lib/test_constructor.py:96:80: E501 line too long (87 > 79 characters)
# tests/lib/test_constructor.py:120:80: E501 line too long (87 > 79 characters)
# tests/lib/test_constructor.py:133:20: F821 undefined name 'cmp'
# tests/lib/test_constructor.py:139:80: E501 line too long (84 > 79 characters)
# tests/lib/test_constructor.py:152:20: F821 undefined name 'cmp'
# tests/lib/test_constructor.py:158:80: E501 line too long (84 > 79 characters)
# tests/lib/test_constructor.py:269:1: D101 Missing docstring in public class
# tests/lib/test_constructor.py:269:12: N801 class name 'ordereddict' should use CapWords convention
# tests/lib/test_constructor.py:296:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:320:80: E501 line too long (89 > 79 characters)
# tests/lib/test_constructor.py:332:1: D103 Missing docstring in public function
# tests/lib/test_constructor.py:336:12: F821 undefined name 'YAML'
# tests/lib/test_emitter.py:1:1: D100 Missing docstring in public module
# tests/lib/test_emitter.py:21:1: D103 Missing docstring in public function
# tests/lib/test_emitter.py:35:1: D103 Missing docstring in public function
# tests/lib/test_emitter.py:50:1: D103 Missing docstring in public function
# tests/lib/test_emitter.py:60:80: E501 line too long (93 > 79 characters)
# tests/lib/test_emitter.py:64:80: E501 line too long (90 > 79 characters)
# tests/lib/test_emitter.py:68:80: E501 line too long (90 > 79 characters)
# tests/lib/test_emitter.py:85:1: D101 Missing docstring in public class
# tests/lib/test_emitter.py:86:1: D102 Missing docstring in public method
# tests/lib/test_emitter.py:99:80: E501 line too long (84 > 79 characters)
# tests/lib/test_emitter.py:117:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:1:1: D100 Missing docstring in public module
# tests/lib/test_errors.py:5:1: E402 module level import not at top of file
# tests/lib/test_errors.py:6:1: E402 module level import not at top of file
# tests/lib/test_errors.py:11:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:26:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:41:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:56:1: D103 Missing docstring in public function
# tests/lib/test_errors.py:72:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:1:1: D100 Missing docstring in public module
# tests/lib/test_input_output.py:9:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:9:1: E302 expected 2 blank lines, found 1
# tests/lib/test_input_output.py:35:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:66:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:75:80: E501 line too long (84 > 79 characters)
# tests/lib/test_input_output.py:77:80: E501 line too long (84 > 79 characters)
# tests/lib/test_input_output.py:85:80: E501 line too long (85 > 79 characters)
# tests/lib/test_input_output.py:94:80: E501 line too long (88 > 79 characters)
# tests/lib/test_input_output.py:120:1: D103 Missing docstring in public function
# tests/lib/test_input_output.py:152:1: D103 Missing docstring in public function
# tests/lib/test_mark.py:1:1: D100 Missing docstring in public module
# tests/lib/test_mark.py:5:1: D103 Missing docstring in public function
# tests/lib/test_mark.py:19:80: E501 line too long (80 > 79 characters)
# tests/lib/test_reader.py:1:1: D100 Missing docstring in public module
# tests/lib/test_reader.py:20:1: D103 Missing docstring in public function
# tests/lib/test_recursive.py:1:1: D100 Missing docstring in public module
# tests/lib/test_recursive.py:5:1: D101 Missing docstring in public class
# tests/lib/test_recursive.py:6:1: D107 Missing docstring in __init__
# tests/lib/test_recursive.py:10:1: D105 Missing docstring in magic method
# tests/lib/test_recursive.py:12:80: E501 line too long (87 > 79 characters)
# tests/lib/test_recursive.py:17:1: D101 Missing docstring in public class
# tests/lib/test_recursive.py:18:1: D105 Missing docstring in magic method
# tests/lib/test_recursive.py:21:1: D105 Missing docstring in magic method
# tests/lib/test_recursive.py:25:1: D103 Missing docstring in public function
# tests/lib/test_representer.py:1:1: D100 Missing docstring in public module
# tests/lib/test_representer.py:7:1: D103 Missing docstring in public function
# tests/lib/test_resolver.py:1:1: D100 Missing docstring in public module
# tests/lib/test_resolver.py:6:1: D103 Missing docstring in public function
# tests/lib/test_resolver.py:39:80: E501 line too long (85 > 79 characters)
# tests/lib/test_resolver.py:41:80: E501 line too long (83 > 79 characters)
# tests/lib/test_resolver.py:43:80: E501 line too long (93 > 79 characters)
# tests/lib/test_resolver.py:70:1: D103 Missing docstring in public function
# tests/lib/test_resolver.py:89:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:1:1: D100 Missing docstring in public module
# tests/lib/test_structure.py:38:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:75:80: E501 line too long (91 > 79 characters)
# tests/lib/test_structure.py:76:80: E501 line too long (89 > 79 characters)
# tests/lib/test_structure.py:82:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:102:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:137:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:174:80: E501 line too long (81 > 79 characters)
# tests/lib/test_structure.py:183:80: E501 line too long (84 > 79 characters)
# tests/lib/test_structure.py:196:80: E501 line too long (82 > 79 characters)
# tests/lib/test_structure.py:199:1: D103 Missing docstring in public function
# tests/lib/test_structure.py:204:12: F821 undefined name 'YAML'
# tests/lib/test_tokens.py:1:1: D100 Missing docstring in public module
# tests/lib/test_tokens.py:46:1: D103 Missing docstring in public function
# tests/lib/test_tokens.py:54:80: E501 line too long (101 > 79 characters)
# tests/lib/test_tokens.py:68:1: D103 Missing docstring in public function
# tests/lib/test_yaml.py:1:1: D100 Missing docstring in public module
# tests/lib/test_yaml_ext.py:1:1: D100 Missing docstring in public module
# tests/lib/test_yaml_ext.py:18:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:18:23: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:25:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:25:24: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:32:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:32:26: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:39:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:39:30: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:46:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:46:23: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:53:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:53:27: N803 argument name 'Loader' should be lowercase
# tests/lib/test_yaml_ext.py:60:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:67:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:74:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:74:36: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:81:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:81:34: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:88:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:88:44: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:95:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:95:34: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:102:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:102:43: N803 argument name 'Dumper' should be lowercase
# tests/lib/test_yaml_ext.py:109:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:116:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:168:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:172:80: E501 line too long (92 > 79 characters)
# tests/lib/test_yaml_ext.py:208:80: E501 line too long (92 > 79 characters)
# tests/lib/test_yaml_ext.py:219:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:267:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:331:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:342:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:356:1: D103 Missing docstring in public function
# tests/lib/test_yaml_ext.py:365:80: E501 line too long (84 > 79 characters)

# %%
# flake8 setup ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 setup.py
# Out:
# setup.py:0:1: E902 FileNotFoundError: [Errno 2] No such file or directory: 'setup.py'

# %% [markdown]
# ---
#
# ### `isort`

# %%
# isort all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df pydantic tests setup.py
# Out:
# ERROR: /workspaces/ruamel-yaml-dev/tests/roundtrip.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/roundtrip.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/roundtrip.py:after	2022-04-23 19:39:38.491195
# @@ -3,9 +3,9 @@
#  """
#  helper routines for testing round trip of commented YAML data
#  """
# +import io
#  import sys
#  import textwrap
# -import io
#  from pathlib import Path
#
#  unset = object()
# @@ -255,7 +255,7 @@
#                  yield d
#
#          def dump(self, data, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert ('stream' in kw) ^ ('compare' in kw)
#              if 'stream' in kw:
# @@ -275,7 +275,7 @@
#              assert res == expected
#
#          def round_trip(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -292,7 +292,7 @@
#              assert res == outp
#
#          def round_trip_all(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -316,7 +316,7 @@
#      safe and run a python program, thereby circumventing any restrictions on module level
#      imports
#      """
# -    from subprocess import check_output, STDOUT, CalledProcessError
# +    from subprocess import STDOUT, CalledProcessError, check_output
#
#      if not hasattr(base_dir, 'hash'):
#          base_dir = Path(str(base_dir))
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:after	2022-04-23 19:39:38.516136
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import re
# +
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip_dump  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_anchor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_anchor.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_anchor.py:after	2022-04-23 19:39:38.571798
# @@ -4,11 +4,12 @@
#  testing of anchors and the aliases referring to them
#  """
#
# +import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump, YAML  # NOQA
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# @@ -462,9 +463,9 @@
#
#  class TestDuplicateKeyThroughAnchor:
#      def test_duplicate_key_00(self):
# -        from ruamel.yaml import version_info
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.constructor import DuplicateKeyFutureWarning, DuplicateKeyError
# +        from ruamel.yaml import YAML, version_info
# +        from ruamel.yaml.constructor import (DuplicateKeyError,
# +                                             DuplicateKeyFutureWarning)
#
#          s = dedent("""\
#          &anchor foo:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_api_change.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_api_change.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_api_change.py:after	2022-04-23 19:39:38.587564
# @@ -6,8 +6,9 @@
#
#  import sys
#  import textwrap
# +from pathlib import Path
# +
#  import pytest
# -from pathlib import Path
#
#
#  class TestNewAPI:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_collections.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_collections.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_collections.py:after	2022-04-23 19:39:38.618205
# @@ -8,9 +8,8 @@
#  """
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestOrderedDict:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comments.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comments.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comments.py:after	2022-04-23 19:39:38.631385
# @@ -10,10 +10,10 @@
#
#  """
#
# +import sys
# +
#  import pytest
# -import sys
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestComments:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:after	2022-04-23 19:39:38.646801
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:after	2022-04-23 19:39:38.658743
# @@ -5,8 +5,8 @@
#  """
#
#  import sys
# +
#  import pytest
# -
#
#  single_doc = """\
#  - a: 1
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_copy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_copy.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_copy.py:after	2022-04-23 19:39:38.671385
# @@ -7,8 +7,7 @@
#  import copy
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestDeepCopy:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_cyaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:after	2022-04-23 19:39:38.681849
# @@ -1,9 +1,10 @@
#  # coding: utf-8
#
# +import platform
#  import sys
# -import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
#
#  NO_CLIB_VER = (3, 10)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_datetime.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_datetime.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_datetime.py:after	2022-04-23 19:39:38.691848
# @@ -20,9 +20,10 @@
#  """
#
#  import copy
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestDateTime:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_deprecation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:after	2022-04-23 19:39:38.702125
# @@ -1,6 +1,7 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_documents.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_documents.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_documents.py:after	2022-04-23 19:39:38.719586
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load_all, round_trip_dump_all
# +from roundtrip import round_trip, round_trip_dump_all, round_trip_load_all
#
#
#  class TestDocument:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_fail.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_fail.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_fail.py:after	2022-04-23 19:39:38.731122
# @@ -7,8 +7,7 @@
#  # and remove remove the xyz_no_fail
#
#  import pytest
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestCommentFailures:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_float.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_float.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_float.py:after	2022-04-23 19:39:38.741815
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_indentation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_indentation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_indentation.py:after	2022-04-23 19:39:38.775416
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, round_trip_dump, dedent, YAML
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,
# +                       round_trip_load)
#
#
#  def rt(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_int.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_int.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_int.py:after	2022-04-23 19:39:38.787664
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_issues.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_issues.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_issues.py:after	2022-04-23 19:39:38.820181
# @@ -1,17 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import (
# -    round_trip,
# -    na_round_trip,
# -    round_trip_load,
# -    round_trip_dump,
# -    dedent,
# -    save_and_run,
# -    YAML,
# -)  # NOQA
# +from roundtrip import (YAML, dedent, na_round_trip, round_trip,  # NOQA
# +                       round_trip_dump, round_trip_load, save_and_run)
#
#
#  class TestIssues:
# @@ -412,16 +403,18 @@
#              yaml.load('{]')
#
#      def test_issue_233(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('{}')
#          json_str = json.dumps(data)  # NOQA
#
#      def test_issue_233a(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('[]')
# @@ -577,10 +570,11 @@
#          assert buf.getvalue() == inp
#
#      def test_issue_280(self):
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.representer import RepresenterError
#          from collections import namedtuple
#          from sys import stdout
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.representer import RepresenterError
#          T = namedtuple('T', ('a', 'b'))
#          t = T(1, 2)
#          yaml = YAML()
# @@ -650,8 +644,9 @@
#
#      def test_issue_288(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -681,8 +676,9 @@
#
#      def test_issue_288a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -712,8 +708,9 @@
#
#      def test_issue_290(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -748,8 +745,9 @@
#
#      def test_issue_290a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:after	2022-04-23 19:39:38.836323
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
# +import json
# +
#  import pytest  # NOQA
# -
# -import json
#
#
#  def load(s, typ=float):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_line_col.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_line_col.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_line_col.py:after	2022-04-23 19:39:38.849474
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_literal.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_literal.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_literal.py:after	2022-04-23 19:39:38.863414
# @@ -1,9 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import YAML  # does an automatic dedent on load
# -
#
#  """
#  YAML 1.0 allowed root level literal style without indentation:
# @@ -63,6 +61,7 @@
#
#      def test_root_literal_scalar_no_indent_1_1_old_style(self):
#          from textwrap import dedent
# +
#          from ruamel.yaml import YAML
#
#          yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_none.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_none.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_none.py:after	2022-04-23 19:39:38.875259
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -from roundtrip import round_trip_load, round_trip_dump
# +from roundtrip import round_trip_dump, round_trip_load
#
#
#  class TestNone:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_program_config.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_program_config.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_program_config.py:after	2022-04-23 19:39:38.903811
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  # import ruamel.yaml
#  from roundtrip import round_trip
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:after	2022-04-23 19:39:38.916858
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
# +import pytest  # NOQA
#  from roundtrip import YAML
# -import pytest  # NOQA
#
#
#  def test_example_2_1():
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_string.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_string.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_string.py:after	2022-04-23 19:39:38.940507
# @@ -13,11 +13,12 @@
#
#  """
#
# +import platform
# +
#  import pytest
# -import platform
# -
#  # from ruamel.yaml.compat import ordereddict
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestLiteralScalarString:
# @@ -189,11 +190,11 @@
#          assert round_trip_dump(data) == dedent(exp)
#
#      def test_map(self):
# +        from ruamel.yaml.comments import CommentedMap
#          from ruamel.yaml.compat import ordereddict
# -        from ruamel.yaml.comments import CommentedMap
# -        from ruamel.yaml.scalarstring import walk_tree, preserve_literal
#          from ruamel.yaml.scalarstring import DoubleQuotedScalarString as dq
#          from ruamel.yaml.scalarstring import SingleQuotedScalarString as sq
# +        from ruamel.yaml.scalarstring import preserve_literal, walk_tree
#
#          data = CommentedMap()
#          data[1] = 'a'
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_tag.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_tag.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_tag.py:after	2022-04-23 19:39:38.952162
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, YAML
# +from roundtrip import YAML, round_trip, round_trip_load
#
#
#  def register_xxx(**kw):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_version.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_version.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_version.py:after	2022-04-23 19:39:38.964605
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip, round_trip_load
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:after	2022-04-23 19:39:38.986446
# @@ -4,12 +4,13 @@
#  various test cases for YAML files
#  """
#
# +import io
# +import platform
#  import sys
# -import io
# +
#  import pytest  # NOQA
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestYAML:
# @@ -21,8 +22,8 @@
#
#      def test_omap_out(self):
#          # ordereddict mapped to !!omap
# +        import ruamel.yaml  # NOQA
#          from ruamel.yaml.compat import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          x = ordereddict([('a', 1), ('b', 2)])
#          res = round_trip_dump(x, default_flow_style=False)
# @@ -44,6 +45,7 @@
#      @pytest.mark.skipif(sys.version_info < (2, 7), reason='collections not available')
#      def test_dump_collections_ordereddict(self):
#          from collections import OrderedDict
# +
#          import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
# @@ -60,8 +62,8 @@
#          reason='ruamel.yaml not available',
#      )
#      def test_dump_ruamel_ordereddict(self):
# +        import ruamel.yaml  # NOQA
#          from ruamel.ordereddict import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
#          x = ordereddict([('a', 1), ('b', 2)])
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:after	2022-04-23 19:39:38.997420
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
#  from roundtrip import save_and_run  # NOQA
#
#
# @@ -70,8 +70,8 @@
#  @pytest.mark.skipif(sys.version_info < (3, 0), reason='no __qualname__')
#  def test_qualified_name01(tmpdir):
#      """issue 214"""
# +    import ruamel.yaml.comments
#      from ruamel.yaml import YAML
# -    import ruamel.yaml.comments
#      from ruamel.yaml.compat import StringIO
#
#      yaml = YAML(typ='unsafe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:after	2022-04-23 19:39:39.009083
# @@ -1,9 +1,9 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip_load, round_trip_dump, dedent
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestLeftOverDebug:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_data.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_data.py:before	2022-04-22 05:17:20.984309
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_data.py:after	2022-04-23 19:39:39.031783
# @@ -1,11 +1,11 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# -import pytest  # NOQA
#  import warnings  # NOQA
#  from pathlib import Path
#
# +import pytest  # NOQA
#  from ruamel.yaml.compat import _F
#
#  base_path = Path('data')  # that is ruamel.yaml.data
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:before	2022-04-22 05:17:12.268005
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:after	2022-04-23 19:39:39.062844
# @@ -1,13 +1,13 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# +
#  import pytest  # NOQA
#
#  sys.path.insert(0, os.path.dirname(__file__) + '/lib')
#
#  import warnings  # NOQA
# -
#
#  args = []
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_all.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:after	2022-04-23 19:39:40.739772
# @@ -1,5 +1,6 @@
#
#  import sys  # NOQA
# +
#  import ruamel.yaml
#  import test_appliance
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:after	2022-04-23 19:39:40.757741
# @@ -1,10 +1,10 @@
#
# +import argparse
# +import os
# +import pprint
#  import sys
# -import os
# +import traceback
#  import types
# -import traceback
# -import pprint
# -import argparse
#
#  # DATA = 'tests/data'
#  # determine the position of data dynamically relative to program
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:after	2022-04-23 19:39:40.775965
# @@ -1,8 +1,8 @@
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -10,7 +10,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml
# -    import test_appliance
#
#      test_appliance.run(test_yaml)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:after	2022-04-23 19:39:40.794677
# @@ -1,9 +1,9 @@
#
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -11,7 +11,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml_ext
# -    import test_appliance
#
#      test_appliance.run(test_yaml_ext)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:after	2022-04-23 19:39:40.819975
# @@ -1,7 +1,7 @@
#
#
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
#
#
#  def test_canonical_scanner(canonical_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:after	2022-04-23 19:39:40.859451
# @@ -1,13 +1,14 @@
# +
# +import datetime
# +import pprint
#
#  import ruamel.yaml
# -import pprint
# -
# -import datetime
#
#  try:
#      set
#  except NameError:
#      from sets import Set as set  # NOQA
# +
#  import ruamel.yaml.tokens
#
#
# @@ -364,6 +365,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_constructor  # NOQA
#
#      sys.modules['test_constructor'] = sys.modules['__main__']
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:after	2022-04-23 19:39:40.880391
# @@ -1,5 +1,4 @@
# -from __future__ import absolute_import
# -from __future__ import print_function
# +from __future__ import absolute_import, print_function
#
#  import ruamel.yaml as yaml
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:after	2022-04-23 19:39:40.915525
# @@ -1,9 +1,11 @@
#
#  import ruamel.yaml
# +
#  YAML = ruamel.yaml.YAML
#
# +import warnings
# +
#  import test_emitter
# -import warnings
#
#  warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:after	2022-04-23 19:39:40.936537
# @@ -1,10 +1,12 @@
# +
# +import codecs
# +import os
# +import os.path
# +import tempfile
#
#  from ruamel.yaml import YAML
# -import codecs
# -import tempfile
# -import os
# -import os.path
# -from ruamel.yaml.compat import StringIO, BytesIO
# +from ruamel.yaml.compat import BytesIO, StringIO
# +
#
#  def test_unicode_input(unicode_filename, verbose=False):
#      yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:before	2022-04-22 05:22:10.737925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:after	2022-04-23 19:39:41.021598
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import test_constructor
#  from ruamel.yaml import YAML
# -import test_constructor
# -import pprint
#
#
#  def test_representer_types(code_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:before	2022-04-22 05:22:10.738925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:after	2022-04-23 19:39:41.040393
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml as yaml
# -import pprint
#
#
#  def test_implicit_resolver(data_filename, detect_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:before	2022-04-22 05:22:10.739925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:after	2022-04-23 19:39:41.060510
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
# -import pprint
#
#
#  def _convert_structure(loader):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:before	2022-04-22 05:22:10.741924
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:after	2022-04-23 19:39:41.082203
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml
# -import pprint
#
#  # Tokens mnemonic:
#  # directive:            %
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:before	2022-04-22 05:22:10.742925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:after	2022-04-23 19:39:41.171302
# @@ -1,20 +1,21 @@
#  # coding: utf-8
#
# +from test_canonical import *  # NOQA
# +from test_constructor import *  # NOQA
# +from test_emitter import *  # NOQA
# +from test_errors import *  # NOQA
# +from test_input_output import *  # NOQA
#  from test_mark import *  # NOQA
#  from test_reader import *  # NOQA
# -from test_canonical import *  # NOQA
# +from test_recursive import *  # NOQA
# +from test_representer import *  # NOQA
# +from test_resolver import *  # NOQA
# +from test_structure import *  # NOQA
#  from test_tokens import *  # NOQA
# -from test_structure import *  # NOQA
# -from test_errors import *  # NOQA
# -from test_resolver import *  # NOQA
# -from test_constructor import *  # NOQA
# -from test_emitter import *  # NOQA
# -from test_representer import *  # NOQA
# -from test_recursive import *  # NOQA
# -from test_input_output import *  # NOQA
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:before	2022-04-22 05:22:10.744925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:after	2022-04-23 19:39:41.198134
# @@ -1,9 +1,10 @@
#  # coding: utf-8
# +
# +import pprint
# +import types
#
#  import _ruamel_yaml
#  import ruamel.yaml
# -import types
# -import pprint
#
#  ruamel.yaml.PyBaseLoader = ruamel.yaml.BaseLoader
#  ruamel.yaml.PySafeLoader = ruamel.yaml.SafeLoader
# @@ -369,15 +370,15 @@
#          globals()[function.__name__] = function
#
#
# -import test_tokens  # NOQA
# -import test_structure  # NOQA
# -import test_errors  # NOQA
# -import test_resolver  # NOQA
#  import test_constructor  # NOQA
#  import test_emitter  # NOQA
# +import test_errors  # NOQA
# +import test_input_output  # NOQA
# +import test_recursive  # NOQA
#  import test_representer  # NOQA
# -import test_recursive  # NOQA
# -import test_input_output  # NOQA
# +import test_resolver  # NOQA
# +import test_structure  # NOQA
# +import test_tokens  # NOQA
#
#  wrap_ext(
#      [
# @@ -395,6 +396,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))
# Broken 2 paths

# %%
# isort pydantic ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df pydantic
# Out:
# Broken 1 paths

# %%
# isort tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df tests
# Out:
# ERROR: /workspaces/ruamel-yaml-dev/tests/roundtrip.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/roundtrip.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/roundtrip.py:after	2022-04-23 19:39:42.215559
# @@ -3,9 +3,9 @@
#  """
#  helper routines for testing round trip of commented YAML data
#  """
# +import io
#  import sys
#  import textwrap
# -import io
#  from pathlib import Path
#
#  unset = object()
# @@ -255,7 +255,7 @@
#                  yield d
#
#          def dump(self, data, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert ('stream' in kw) ^ ('compare' in kw)
#              if 'stream' in kw:
# @@ -275,7 +275,7 @@
#              assert res == expected
#
#          def round_trip(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -292,7 +292,7 @@
#              assert res == outp
#
#          def round_trip_all(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -316,7 +316,7 @@
#      safe and run a python program, thereby circumventing any restrictions on module level
#      imports
#      """
# -    from subprocess import check_output, STDOUT, CalledProcessError
# +    from subprocess import STDOUT, CalledProcessError, check_output
#
#      if not hasattr(base_dir, 'hash'):
#          base_dir = Path(str(base_dir))
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:after	2022-04-23 19:39:42.238857
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import re
# +
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip_dump  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_anchor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_anchor.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_anchor.py:after	2022-04-23 19:39:42.293683
# @@ -4,11 +4,12 @@
#  testing of anchors and the aliases referring to them
#  """
#
# +import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump, YAML  # NOQA
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# @@ -462,9 +463,9 @@
#
#  class TestDuplicateKeyThroughAnchor:
#      def test_duplicate_key_00(self):
# -        from ruamel.yaml import version_info
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.constructor import DuplicateKeyFutureWarning, DuplicateKeyError
# +        from ruamel.yaml import YAML, version_info
# +        from ruamel.yaml.constructor import (DuplicateKeyError,
# +                                             DuplicateKeyFutureWarning)
#
#          s = dedent("""\
#          &anchor foo:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_api_change.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_api_change.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_api_change.py:after	2022-04-23 19:39:42.311452
# @@ -6,8 +6,9 @@
#
#  import sys
#  import textwrap
# +from pathlib import Path
# +
#  import pytest
# -from pathlib import Path
#
#
#  class TestNewAPI:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_collections.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_collections.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_collections.py:after	2022-04-23 19:39:42.340974
# @@ -8,9 +8,8 @@
#  """
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestOrderedDict:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comments.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comments.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comments.py:after	2022-04-23 19:39:42.355309
# @@ -10,10 +10,10 @@
#
#  """
#
# +import sys
# +
#  import pytest
# -import sys
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestComments:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:after	2022-04-23 19:39:42.370645
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:after	2022-04-23 19:39:42.382515
# @@ -5,8 +5,8 @@
#  """
#
#  import sys
# +
#  import pytest
# -
#
#  single_doc = """\
#  - a: 1
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_copy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_copy.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_copy.py:after	2022-04-23 19:39:42.392652
# @@ -7,8 +7,7 @@
#  import copy
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestDeepCopy:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_cyaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:after	2022-04-23 19:39:42.404062
# @@ -1,9 +1,10 @@
#  # coding: utf-8
#
# +import platform
#  import sys
# -import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
#
#  NO_CLIB_VER = (3, 10)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_datetime.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_datetime.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_datetime.py:after	2022-04-23 19:39:42.414468
# @@ -20,9 +20,10 @@
#  """
#
#  import copy
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestDateTime:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_deprecation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:after	2022-04-23 19:39:42.426021
# @@ -1,6 +1,7 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_documents.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_documents.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_documents.py:after	2022-04-23 19:39:42.441958
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load_all, round_trip_dump_all
# +from roundtrip import round_trip, round_trip_dump_all, round_trip_load_all
#
#
#  class TestDocument:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_fail.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_fail.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_fail.py:after	2022-04-23 19:39:42.453368
# @@ -7,8 +7,7 @@
#  # and remove remove the xyz_no_fail
#
#  import pytest
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestCommentFailures:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_float.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_float.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_float.py:after	2022-04-23 19:39:42.464029
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_indentation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_indentation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_indentation.py:after	2022-04-23 19:39:42.492696
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, round_trip_dump, dedent, YAML
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,
# +                       round_trip_load)
#
#
#  def rt(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_int.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_int.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_int.py:after	2022-04-23 19:39:42.502507
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_issues.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_issues.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_issues.py:after	2022-04-23 19:39:42.532120
# @@ -1,17 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import (
# -    round_trip,
# -    na_round_trip,
# -    round_trip_load,
# -    round_trip_dump,
# -    dedent,
# -    save_and_run,
# -    YAML,
# -)  # NOQA
# +from roundtrip import (YAML, dedent, na_round_trip, round_trip,  # NOQA
# +                       round_trip_dump, round_trip_load, save_and_run)
#
#
#  class TestIssues:
# @@ -412,16 +403,18 @@
#              yaml.load('{]')
#
#      def test_issue_233(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('{}')
#          json_str = json.dumps(data)  # NOQA
#
#      def test_issue_233a(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('[]')
# @@ -577,10 +570,11 @@
#          assert buf.getvalue() == inp
#
#      def test_issue_280(self):
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.representer import RepresenterError
#          from collections import namedtuple
#          from sys import stdout
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.representer import RepresenterError
#          T = namedtuple('T', ('a', 'b'))
#          t = T(1, 2)
#          yaml = YAML()
# @@ -650,8 +644,9 @@
#
#      def test_issue_288(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -681,8 +676,9 @@
#
#      def test_issue_288a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -712,8 +708,9 @@
#
#      def test_issue_290(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -748,8 +745,9 @@
#
#      def test_issue_290a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:after	2022-04-23 19:39:42.543898
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
# +import json
# +
#  import pytest  # NOQA
# -
# -import json
#
#
#  def load(s, typ=float):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_line_col.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_line_col.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_line_col.py:after	2022-04-23 19:39:42.554169
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_literal.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_literal.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_literal.py:after	2022-04-23 19:39:42.568009
# @@ -1,9 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import YAML  # does an automatic dedent on load
# -
#
#  """
#  YAML 1.0 allowed root level literal style without indentation:
# @@ -63,6 +61,7 @@
#
#      def test_root_literal_scalar_no_indent_1_1_old_style(self):
#          from textwrap import dedent
# +
#          from ruamel.yaml import YAML
#
#          yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_none.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_none.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_none.py:after	2022-04-23 19:39:42.583597
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -from roundtrip import round_trip_load, round_trip_dump
# +from roundtrip import round_trip_dump, round_trip_load
#
#
#  class TestNone:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_program_config.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_program_config.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_program_config.py:after	2022-04-23 19:39:42.618344
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  # import ruamel.yaml
#  from roundtrip import round_trip
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:after	2022-04-23 19:39:42.633530
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
# +import pytest  # NOQA
#  from roundtrip import YAML
# -import pytest  # NOQA
#
#
#  def test_example_2_1():
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_string.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_string.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_string.py:after	2022-04-23 19:39:42.660922
# @@ -13,11 +13,12 @@
#
#  """
#
# +import platform
# +
#  import pytest
# -import platform
# -
#  # from ruamel.yaml.compat import ordereddict
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestLiteralScalarString:
# @@ -189,11 +190,11 @@
#          assert round_trip_dump(data) == dedent(exp)
#
#      def test_map(self):
# +        from ruamel.yaml.comments import CommentedMap
#          from ruamel.yaml.compat import ordereddict
# -        from ruamel.yaml.comments import CommentedMap
# -        from ruamel.yaml.scalarstring import walk_tree, preserve_literal
#          from ruamel.yaml.scalarstring import DoubleQuotedScalarString as dq
#          from ruamel.yaml.scalarstring import SingleQuotedScalarString as sq
# +        from ruamel.yaml.scalarstring import preserve_literal, walk_tree
#
#          data = CommentedMap()
#          data[1] = 'a'
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_tag.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_tag.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_tag.py:after	2022-04-23 19:39:42.677397
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, YAML
# +from roundtrip import YAML, round_trip, round_trip_load
#
#
#  def register_xxx(**kw):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_version.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_version.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_version.py:after	2022-04-23 19:39:42.695700
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip, round_trip_load
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:after	2022-04-23 19:39:42.720111
# @@ -4,12 +4,13 @@
#  various test cases for YAML files
#  """
#
# +import io
# +import platform
#  import sys
# -import io
# +
#  import pytest  # NOQA
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestYAML:
# @@ -21,8 +22,8 @@
#
#      def test_omap_out(self):
#          # ordereddict mapped to !!omap
# +        import ruamel.yaml  # NOQA
#          from ruamel.yaml.compat import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          x = ordereddict([('a', 1), ('b', 2)])
#          res = round_trip_dump(x, default_flow_style=False)
# @@ -44,6 +45,7 @@
#      @pytest.mark.skipif(sys.version_info < (2, 7), reason='collections not available')
#      def test_dump_collections_ordereddict(self):
#          from collections import OrderedDict
# +
#          import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
# @@ -60,8 +62,8 @@
#          reason='ruamel.yaml not available',
#      )
#      def test_dump_ruamel_ordereddict(self):
# +        import ruamel.yaml  # NOQA
#          from ruamel.ordereddict import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
#          x = ordereddict([('a', 1), ('b', 2)])
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:after	2022-04-23 19:39:42.732991
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
#  from roundtrip import save_and_run  # NOQA
#
#
# @@ -70,8 +70,8 @@
#  @pytest.mark.skipif(sys.version_info < (3, 0), reason='no __qualname__')
#  def test_qualified_name01(tmpdir):
#      """issue 214"""
# +    import ruamel.yaml.comments
#      from ruamel.yaml import YAML
# -    import ruamel.yaml.comments
#      from ruamel.yaml.compat import StringIO
#
#      yaml = YAML(typ='unsafe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:after	2022-04-23 19:39:42.742606
# @@ -1,9 +1,9 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip_load, round_trip_dump, dedent
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestLeftOverDebug:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_data.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_data.py:before	2022-04-22 05:17:20.984309
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_data.py:after	2022-04-23 19:39:42.762786
# @@ -1,11 +1,11 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# -import pytest  # NOQA
#  import warnings  # NOQA
#  from pathlib import Path
#
# +import pytest  # NOQA
#  from ruamel.yaml.compat import _F
#
#  base_path = Path('data')  # that is ruamel.yaml.data
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:before	2022-04-22 05:17:12.268005
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:after	2022-04-23 19:39:42.797258
# @@ -1,13 +1,13 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# +
#  import pytest  # NOQA
#
#  sys.path.insert(0, os.path.dirname(__file__) + '/lib')
#
#  import warnings  # NOQA
# -
#
#  args = []
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_all.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:after	2022-04-23 19:39:44.356778
# @@ -1,5 +1,6 @@
#
#  import sys  # NOQA
# +
#  import ruamel.yaml
#  import test_appliance
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:after	2022-04-23 19:39:44.371746
# @@ -1,10 +1,10 @@
#
# +import argparse
# +import os
# +import pprint
#  import sys
# -import os
# +import traceback
#  import types
# -import traceback
# -import pprint
# -import argparse
#
#  # DATA = 'tests/data'
#  # determine the position of data dynamically relative to program
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:after	2022-04-23 19:39:44.387083
# @@ -1,8 +1,8 @@
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -10,7 +10,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml
# -    import test_appliance
#
#      test_appliance.run(test_yaml)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:after	2022-04-23 19:39:44.403157
# @@ -1,9 +1,9 @@
#
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -11,7 +11,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml_ext
# -    import test_appliance
#
#      test_appliance.run(test_yaml_ext)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:after	2022-04-23 19:39:44.425103
# @@ -1,7 +1,7 @@
#
#
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
#
#
#  def test_canonical_scanner(canonical_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:after	2022-04-23 19:39:44.455487
# @@ -1,13 +1,14 @@
# +
# +import datetime
# +import pprint
#
#  import ruamel.yaml
# -import pprint
# -
# -import datetime
#
#  try:
#      set
#  except NameError:
#      from sets import Set as set  # NOQA
# +
#  import ruamel.yaml.tokens
#
#
# @@ -364,6 +365,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_constructor  # NOQA
#
#      sys.modules['test_constructor'] = sys.modules['__main__']
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:after	2022-04-23 19:39:44.469844
# @@ -1,5 +1,4 @@
# -from __future__ import absolute_import
# -from __future__ import print_function
# +from __future__ import absolute_import, print_function
#
#  import ruamel.yaml as yaml
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:after	2022-04-23 19:39:44.498221
# @@ -1,9 +1,11 @@
#
#  import ruamel.yaml
# +
#  YAML = ruamel.yaml.YAML
#
# +import warnings
# +
#  import test_emitter
# -import warnings
#
#  warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:after	2022-04-23 19:39:44.516259
# @@ -1,10 +1,12 @@
# +
# +import codecs
# +import os
# +import os.path
# +import tempfile
#
#  from ruamel.yaml import YAML
# -import codecs
# -import tempfile
# -import os
# -import os.path
# -from ruamel.yaml.compat import StringIO, BytesIO
# +from ruamel.yaml.compat import BytesIO, StringIO
# +
#
#  def test_unicode_input(unicode_filename, verbose=False):
#      yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:before	2022-04-22 05:22:10.737925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:after	2022-04-23 19:39:44.578977
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import test_constructor
#  from ruamel.yaml import YAML
# -import test_constructor
# -import pprint
#
#
#  def test_representer_types(code_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:before	2022-04-22 05:22:10.738925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:after	2022-04-23 19:39:44.592430
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml as yaml
# -import pprint
#
#
#  def test_implicit_resolver(data_filename, detect_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:before	2022-04-22 05:22:10.739925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:after	2022-04-23 19:39:44.609397
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
# -import pprint
#
#
#  def _convert_structure(loader):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:before	2022-04-22 05:22:10.741924
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:after	2022-04-23 19:39:44.623293
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml
# -import pprint
#
#  # Tokens mnemonic:
#  # directive:            %
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:before	2022-04-22 05:22:10.742925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:after	2022-04-23 19:39:44.698941
# @@ -1,20 +1,21 @@
#  # coding: utf-8
#
# +from test_canonical import *  # NOQA
# +from test_constructor import *  # NOQA
# +from test_emitter import *  # NOQA
# +from test_errors import *  # NOQA
# +from test_input_output import *  # NOQA
#  from test_mark import *  # NOQA
#  from test_reader import *  # NOQA
# -from test_canonical import *  # NOQA
# +from test_recursive import *  # NOQA
# +from test_representer import *  # NOQA
# +from test_resolver import *  # NOQA
# +from test_structure import *  # NOQA
#  from test_tokens import *  # NOQA
# -from test_structure import *  # NOQA
# -from test_errors import *  # NOQA
# -from test_resolver import *  # NOQA
# -from test_constructor import *  # NOQA
# -from test_emitter import *  # NOQA
# -from test_representer import *  # NOQA
# -from test_recursive import *  # NOQA
# -from test_input_output import *  # NOQA
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:before	2022-04-22 05:22:10.744925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:after	2022-04-23 19:39:44.722691
# @@ -1,9 +1,10 @@
#  # coding: utf-8
# +
# +import pprint
# +import types
#
#  import _ruamel_yaml
#  import ruamel.yaml
# -import types
# -import pprint
#
#  ruamel.yaml.PyBaseLoader = ruamel.yaml.BaseLoader
#  ruamel.yaml.PySafeLoader = ruamel.yaml.SafeLoader
# @@ -369,15 +370,15 @@
#          globals()[function.__name__] = function
#
#
# -import test_tokens  # NOQA
# -import test_structure  # NOQA
# -import test_errors  # NOQA
# -import test_resolver  # NOQA
#  import test_constructor  # NOQA
#  import test_emitter  # NOQA
# +import test_errors  # NOQA
# +import test_input_output  # NOQA
# +import test_recursive  # NOQA
#  import test_representer  # NOQA
# -import test_recursive  # NOQA
# -import test_input_output  # NOQA
# +import test_resolver  # NOQA
# +import test_structure  # NOQA
# +import test_tokens  # NOQA
#
#  wrap_ext(
#      [
# @@ -395,6 +396,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))

# %%
# isort setup ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df setup.py
# Out:
# Broken 1 paths

# %% [markdown]
# ---
#
# ### `black`

# %%
# isort all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df pydantic tests setup.py
# Out:
# ERROR: /workspaces/ruamel-yaml-dev/tests/roundtrip.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/roundtrip.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/roundtrip.py:after	2022-04-23 19:39:45.660015
# @@ -3,9 +3,9 @@
#  """
#  helper routines for testing round trip of commented YAML data
#  """
# +import io
#  import sys
#  import textwrap
# -import io
#  from pathlib import Path
#
#  unset = object()
# @@ -255,7 +255,7 @@
#                  yield d
#
#          def dump(self, data, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert ('stream' in kw) ^ ('compare' in kw)
#              if 'stream' in kw:
# @@ -275,7 +275,7 @@
#              assert res == expected
#
#          def round_trip(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -292,7 +292,7 @@
#              assert res == outp
#
#          def round_trip_all(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -316,7 +316,7 @@
#      safe and run a python program, thereby circumventing any restrictions on module level
#      imports
#      """
# -    from subprocess import check_output, STDOUT, CalledProcessError
# +    from subprocess import STDOUT, CalledProcessError, check_output
#
#      if not hasattr(base_dir, 'hash'):
#          base_dir = Path(str(base_dir))
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:after	2022-04-23 19:39:45.681694
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import re
# +
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip_dump  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_anchor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_anchor.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_anchor.py:after	2022-04-23 19:39:45.733999
# @@ -4,11 +4,12 @@
#  testing of anchors and the aliases referring to them
#  """
#
# +import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump, YAML  # NOQA
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# @@ -462,9 +463,9 @@
#
#  class TestDuplicateKeyThroughAnchor:
#      def test_duplicate_key_00(self):
# -        from ruamel.yaml import version_info
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.constructor import DuplicateKeyFutureWarning, DuplicateKeyError
# +        from ruamel.yaml import YAML, version_info
# +        from ruamel.yaml.constructor import (DuplicateKeyError,
# +                                             DuplicateKeyFutureWarning)
#
#          s = dedent("""\
#          &anchor foo:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_api_change.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_api_change.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_api_change.py:after	2022-04-23 19:39:45.751267
# @@ -6,8 +6,9 @@
#
#  import sys
#  import textwrap
# +from pathlib import Path
# +
#  import pytest
# -from pathlib import Path
#
#
#  class TestNewAPI:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_collections.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_collections.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_collections.py:after	2022-04-23 19:39:45.779536
# @@ -8,9 +8,8 @@
#  """
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestOrderedDict:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comments.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comments.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comments.py:after	2022-04-23 19:39:45.793584
# @@ -10,10 +10,10 @@
#
#  """
#
# +import sys
# +
#  import pytest
# -import sys
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestComments:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:after	2022-04-23 19:39:45.807573
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:after	2022-04-23 19:39:45.818829
# @@ -5,8 +5,8 @@
#  """
#
#  import sys
# +
#  import pytest
# -
#
#  single_doc = """\
#  - a: 1
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_copy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_copy.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_copy.py:after	2022-04-23 19:39:45.829538
# @@ -7,8 +7,7 @@
#  import copy
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestDeepCopy:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_cyaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:after	2022-04-23 19:39:45.841302
# @@ -1,9 +1,10 @@
#  # coding: utf-8
#
# +import platform
#  import sys
# -import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
#
#  NO_CLIB_VER = (3, 10)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_datetime.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_datetime.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_datetime.py:after	2022-04-23 19:39:45.850924
# @@ -20,9 +20,10 @@
#  """
#
#  import copy
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestDateTime:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_deprecation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:after	2022-04-23 19:39:45.860440
# @@ -1,6 +1,7 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_documents.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_documents.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_documents.py:after	2022-04-23 19:39:45.879615
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load_all, round_trip_dump_all
# +from roundtrip import round_trip, round_trip_dump_all, round_trip_load_all
#
#
#  class TestDocument:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_fail.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_fail.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_fail.py:after	2022-04-23 19:39:45.891629
# @@ -7,8 +7,7 @@
#  # and remove remove the xyz_no_fail
#
#  import pytest
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestCommentFailures:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_float.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_float.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_float.py:after	2022-04-23 19:39:45.901821
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_indentation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_indentation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_indentation.py:after	2022-04-23 19:39:45.928865
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, round_trip_dump, dedent, YAML
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,
# +                       round_trip_load)
#
#
#  def rt(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_int.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_int.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_int.py:after	2022-04-23 19:39:45.939871
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_issues.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_issues.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_issues.py:after	2022-04-23 19:39:45.966249
# @@ -1,17 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import (
# -    round_trip,
# -    na_round_trip,
# -    round_trip_load,
# -    round_trip_dump,
# -    dedent,
# -    save_and_run,
# -    YAML,
# -)  # NOQA
# +from roundtrip import (YAML, dedent, na_round_trip, round_trip,  # NOQA
# +                       round_trip_dump, round_trip_load, save_and_run)
#
#
#  class TestIssues:
# @@ -412,16 +403,18 @@
#              yaml.load('{]')
#
#      def test_issue_233(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('{}')
#          json_str = json.dumps(data)  # NOQA
#
#      def test_issue_233a(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('[]')
# @@ -577,10 +570,11 @@
#          assert buf.getvalue() == inp
#
#      def test_issue_280(self):
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.representer import RepresenterError
#          from collections import namedtuple
#          from sys import stdout
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.representer import RepresenterError
#          T = namedtuple('T', ('a', 'b'))
#          t = T(1, 2)
#          yaml = YAML()
# @@ -650,8 +644,9 @@
#
#      def test_issue_288(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -681,8 +676,9 @@
#
#      def test_issue_288a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -712,8 +708,9 @@
#
#      def test_issue_290(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -748,8 +745,9 @@
#
#      def test_issue_290a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:after	2022-04-23 19:39:45.977501
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
# +import json
# +
#  import pytest  # NOQA
# -
# -import json
#
#
#  def load(s, typ=float):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_line_col.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_line_col.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_line_col.py:after	2022-04-23 19:39:45.988280
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_literal.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_literal.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_literal.py:after	2022-04-23 19:39:45.999250
# @@ -1,9 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import YAML  # does an automatic dedent on load
# -
#
#  """
#  YAML 1.0 allowed root level literal style without indentation:
# @@ -63,6 +61,7 @@
#
#      def test_root_literal_scalar_no_indent_1_1_old_style(self):
#          from textwrap import dedent
# +
#          from ruamel.yaml import YAML
#
#          yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_none.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_none.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_none.py:after	2022-04-23 19:39:46.008642
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -from roundtrip import round_trip_load, round_trip_dump
# +from roundtrip import round_trip_dump, round_trip_load
#
#
#  class TestNone:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_program_config.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_program_config.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_program_config.py:after	2022-04-23 19:39:46.033895
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  # import ruamel.yaml
#  from roundtrip import round_trip
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:after	2022-04-23 19:39:46.045118
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
# +import pytest  # NOQA
#  from roundtrip import YAML
# -import pytest  # NOQA
#
#
#  def test_example_2_1():
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_string.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_string.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_string.py:after	2022-04-23 19:39:46.064159
# @@ -13,11 +13,12 @@
#
#  """
#
# +import platform
# +
#  import pytest
# -import platform
# -
#  # from ruamel.yaml.compat import ordereddict
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestLiteralScalarString:
# @@ -189,11 +190,11 @@
#          assert round_trip_dump(data) == dedent(exp)
#
#      def test_map(self):
# +        from ruamel.yaml.comments import CommentedMap
#          from ruamel.yaml.compat import ordereddict
# -        from ruamel.yaml.comments import CommentedMap
# -        from ruamel.yaml.scalarstring import walk_tree, preserve_literal
#          from ruamel.yaml.scalarstring import DoubleQuotedScalarString as dq
#          from ruamel.yaml.scalarstring import SingleQuotedScalarString as sq
# +        from ruamel.yaml.scalarstring import preserve_literal, walk_tree
#
#          data = CommentedMap()
#          data[1] = 'a'
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_tag.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_tag.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_tag.py:after	2022-04-23 19:39:46.074654
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, YAML
# +from roundtrip import YAML, round_trip, round_trip_load
#
#
#  def register_xxx(**kw):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_version.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_version.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_version.py:after	2022-04-23 19:39:46.086922
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip, round_trip_load
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:after	2022-04-23 19:39:46.106962
# @@ -4,12 +4,13 @@
#  various test cases for YAML files
#  """
#
# +import io
# +import platform
#  import sys
# -import io
# +
#  import pytest  # NOQA
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestYAML:
# @@ -21,8 +22,8 @@
#
#      def test_omap_out(self):
#          # ordereddict mapped to !!omap
# +        import ruamel.yaml  # NOQA
#          from ruamel.yaml.compat import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          x = ordereddict([('a', 1), ('b', 2)])
#          res = round_trip_dump(x, default_flow_style=False)
# @@ -44,6 +45,7 @@
#      @pytest.mark.skipif(sys.version_info < (2, 7), reason='collections not available')
#      def test_dump_collections_ordereddict(self):
#          from collections import OrderedDict
# +
#          import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
# @@ -60,8 +62,8 @@
#          reason='ruamel.yaml not available',
#      )
#      def test_dump_ruamel_ordereddict(self):
# +        import ruamel.yaml  # NOQA
#          from ruamel.ordereddict import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
#          x = ordereddict([('a', 1), ('b', 2)])
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:after	2022-04-23 19:39:46.117373
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
#  from roundtrip import save_and_run  # NOQA
#
#
# @@ -70,8 +70,8 @@
#  @pytest.mark.skipif(sys.version_info < (3, 0), reason='no __qualname__')
#  def test_qualified_name01(tmpdir):
#      """issue 214"""
# +    import ruamel.yaml.comments
#      from ruamel.yaml import YAML
# -    import ruamel.yaml.comments
#      from ruamel.yaml.compat import StringIO
#
#      yaml = YAML(typ='unsafe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:after	2022-04-23 19:39:46.127439
# @@ -1,9 +1,9 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip_load, round_trip_dump, dedent
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestLeftOverDebug:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_data.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_data.py:before	2022-04-22 05:17:20.984309
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_data.py:after	2022-04-23 19:39:46.148703
# @@ -1,11 +1,11 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# -import pytest  # NOQA
#  import warnings  # NOQA
#  from pathlib import Path
#
# +import pytest  # NOQA
#  from ruamel.yaml.compat import _F
#
#  base_path = Path('data')  # that is ruamel.yaml.data
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:before	2022-04-22 05:17:12.268005
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:after	2022-04-23 19:39:46.177491
# @@ -1,13 +1,13 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# +
#  import pytest  # NOQA
#
#  sys.path.insert(0, os.path.dirname(__file__) + '/lib')
#
#  import warnings  # NOQA
# -
#
#  args = []
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_all.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:after	2022-04-23 19:39:47.711150
# @@ -1,5 +1,6 @@
#
#  import sys  # NOQA
# +
#  import ruamel.yaml
#  import test_appliance
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:after	2022-04-23 19:39:47.726821
# @@ -1,10 +1,10 @@
#
# +import argparse
# +import os
# +import pprint
#  import sys
# -import os
# +import traceback
#  import types
# -import traceback
# -import pprint
# -import argparse
#
#  # DATA = 'tests/data'
#  # determine the position of data dynamically relative to program
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:after	2022-04-23 19:39:47.746605
# @@ -1,8 +1,8 @@
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -10,7 +10,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml
# -    import test_appliance
#
#      test_appliance.run(test_yaml)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:after	2022-04-23 19:39:47.764833
# @@ -1,9 +1,9 @@
#
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -11,7 +11,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml_ext
# -    import test_appliance
#
#      test_appliance.run(test_yaml_ext)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:after	2022-04-23 19:39:47.787294
# @@ -1,7 +1,7 @@
#
#
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
#
#
#  def test_canonical_scanner(canonical_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:after	2022-04-23 19:39:47.819057
# @@ -1,13 +1,14 @@
# +
# +import datetime
# +import pprint
#
#  import ruamel.yaml
# -import pprint
# -
# -import datetime
#
#  try:
#      set
#  except NameError:
#      from sets import Set as set  # NOQA
# +
#  import ruamel.yaml.tokens
#
#
# @@ -364,6 +365,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_constructor  # NOQA
#
#      sys.modules['test_constructor'] = sys.modules['__main__']
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:after	2022-04-23 19:39:47.835931
# @@ -1,5 +1,4 @@
# -from __future__ import absolute_import
# -from __future__ import print_function
# +from __future__ import absolute_import, print_function
#
#  import ruamel.yaml as yaml
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:after	2022-04-23 19:39:47.866511
# @@ -1,9 +1,11 @@
#
#  import ruamel.yaml
# +
#  YAML = ruamel.yaml.YAML
#
# +import warnings
# +
#  import test_emitter
# -import warnings
#
#  warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:after	2022-04-23 19:39:47.881860
# @@ -1,10 +1,12 @@
# +
# +import codecs
# +import os
# +import os.path
# +import tempfile
#
#  from ruamel.yaml import YAML
# -import codecs
# -import tempfile
# -import os
# -import os.path
# -from ruamel.yaml.compat import StringIO, BytesIO
# +from ruamel.yaml.compat import BytesIO, StringIO
# +
#
#  def test_unicode_input(unicode_filename, verbose=False):
#      yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:before	2022-04-22 05:22:10.737925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:after	2022-04-23 19:39:47.944702
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import test_constructor
#  from ruamel.yaml import YAML
# -import test_constructor
# -import pprint
#
#
#  def test_representer_types(code_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:before	2022-04-22 05:22:10.738925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:after	2022-04-23 19:39:47.958961
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml as yaml
# -import pprint
#
#
#  def test_implicit_resolver(data_filename, detect_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:before	2022-04-22 05:22:10.739925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:after	2022-04-23 19:39:47.974046
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
# -import pprint
#
#
#  def _convert_structure(loader):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:before	2022-04-22 05:22:10.741924
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:after	2022-04-23 19:39:47.988857
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml
# -import pprint
#
#  # Tokens mnemonic:
#  # directive:            %
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:before	2022-04-22 05:22:10.742925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:after	2022-04-23 19:39:48.064898
# @@ -1,20 +1,21 @@
#  # coding: utf-8
#
# +from test_canonical import *  # NOQA
# +from test_constructor import *  # NOQA
# +from test_emitter import *  # NOQA
# +from test_errors import *  # NOQA
# +from test_input_output import *  # NOQA
#  from test_mark import *  # NOQA
#  from test_reader import *  # NOQA
# -from test_canonical import *  # NOQA
# +from test_recursive import *  # NOQA
# +from test_representer import *  # NOQA
# +from test_resolver import *  # NOQA
# +from test_structure import *  # NOQA
#  from test_tokens import *  # NOQA
# -from test_structure import *  # NOQA
# -from test_errors import *  # NOQA
# -from test_resolver import *  # NOQA
# -from test_constructor import *  # NOQA
# -from test_emitter import *  # NOQA
# -from test_representer import *  # NOQA
# -from test_recursive import *  # NOQA
# -from test_input_output import *  # NOQA
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:before	2022-04-22 05:22:10.744925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:after	2022-04-23 19:39:48.087577
# @@ -1,9 +1,10 @@
#  # coding: utf-8
# +
# +import pprint
# +import types
#
#  import _ruamel_yaml
#  import ruamel.yaml
# -import types
# -import pprint
#
#  ruamel.yaml.PyBaseLoader = ruamel.yaml.BaseLoader
#  ruamel.yaml.PySafeLoader = ruamel.yaml.SafeLoader
# @@ -369,15 +370,15 @@
#          globals()[function.__name__] = function
#
#
# -import test_tokens  # NOQA
# -import test_structure  # NOQA
# -import test_errors  # NOQA
# -import test_resolver  # NOQA
#  import test_constructor  # NOQA
#  import test_emitter  # NOQA
# +import test_errors  # NOQA
# +import test_input_output  # NOQA
# +import test_recursive  # NOQA
#  import test_representer  # NOQA
# -import test_recursive  # NOQA
# -import test_input_output  # NOQA
# +import test_resolver  # NOQA
# +import test_structure  # NOQA
# +import test_tokens  # NOQA
#
#  wrap_ext(
#      [
# @@ -395,6 +396,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))
# Broken 2 paths

# %%
# isort pydantic ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df pydantic
# Out:
# Broken 1 paths

# %%
# isort tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df tests
# Out:
# ERROR: /workspaces/ruamel-yaml-dev/tests/roundtrip.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/roundtrip.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/roundtrip.py:after	2022-04-23 19:39:49.042960
# @@ -3,9 +3,9 @@
#  """
#  helper routines for testing round trip of commented YAML data
#  """
# +import io
#  import sys
#  import textwrap
# -import io
#  from pathlib import Path
#
#  unset = object()
# @@ -255,7 +255,7 @@
#                  yield d
#
#          def dump(self, data, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert ('stream' in kw) ^ ('compare' in kw)
#              if 'stream' in kw:
# @@ -275,7 +275,7 @@
#              assert res == expected
#
#          def round_trip(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -292,7 +292,7 @@
#              assert res == outp
#
#          def round_trip_all(self, stream, **kw):
# -            from ruamel.yaml.compat import StringIO, BytesIO  # NOQA
# +            from ruamel.yaml.compat import BytesIO, StringIO  # NOQA
#
#              assert isinstance(stream, str)
#              lkw = kw.copy()
# @@ -316,7 +316,7 @@
#      safe and run a python program, thereby circumventing any restrictions on module level
#      imports
#      """
# -    from subprocess import check_output, STDOUT, CalledProcessError
# +    from subprocess import STDOUT, CalledProcessError, check_output
#
#      if not hasattr(base_dir, 'hash'):
#          base_dir = Path(str(base_dir))
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py:after	2022-04-23 19:39:49.065313
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import re
# +
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip_dump  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_anchor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_anchor.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_anchor.py:after	2022-04-23 19:39:49.119483
# @@ -4,11 +4,12 @@
#  testing of anchors and the aliases referring to them
#  """
#
# +import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump, YAML  # NOQA
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# @@ -462,9 +463,9 @@
#
#  class TestDuplicateKeyThroughAnchor:
#      def test_duplicate_key_00(self):
# -        from ruamel.yaml import version_info
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.constructor import DuplicateKeyFutureWarning, DuplicateKeyError
# +        from ruamel.yaml import YAML, version_info
# +        from ruamel.yaml.constructor import (DuplicateKeyError,
# +                                             DuplicateKeyFutureWarning)
#
#          s = dedent("""\
#          &anchor foo:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_api_change.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_api_change.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_api_change.py:after	2022-04-23 19:39:49.140107
# @@ -6,8 +6,9 @@
#
#  import sys
#  import textwrap
# +from pathlib import Path
# +
#  import pytest
# -from pathlib import Path
#
#
#  class TestNewAPI:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_collections.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_collections.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_collections.py:after	2022-04-23 19:39:49.171936
# @@ -8,9 +8,8 @@
#  """
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestOrderedDict:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comments.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comments.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comments.py:after	2022-04-23 19:39:49.184870
# @@ -10,10 +10,10 @@
#
#  """
#
# +import sys
# +
#  import pytest
# -import sys
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestComments:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py:after	2022-04-23 19:39:49.198157
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py:after	2022-04-23 19:39:49.210329
# @@ -5,8 +5,8 @@
#  """
#
#  import sys
# +
#  import pytest
# -
#
#  single_doc = """\
#  - a: 1
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_copy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_copy.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_copy.py:after	2022-04-23 19:39:49.221975
# @@ -7,8 +7,7 @@
#  import copy
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestDeepCopy:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_cyaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_cyaml.py:after	2022-04-23 19:39:49.233305
# @@ -1,9 +1,10 @@
#  # coding: utf-8
#
# +import platform
#  import sys
# -import platform
# +from textwrap import dedent
# +
#  import pytest
# -from textwrap import dedent
#
#  NO_CLIB_VER = (3, 10)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_datetime.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_datetime.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_datetime.py:after	2022-04-23 19:39:49.242612
# @@ -20,9 +20,10 @@
#  """
#
#  import copy
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestDateTime:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_deprecation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_deprecation.py:after	2022-04-23 19:39:49.252513
# @@ -1,6 +1,7 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_documents.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_documents.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_documents.py:after	2022-04-23 19:39:49.269928
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load_all, round_trip_dump_all
# +from roundtrip import round_trip, round_trip_dump_all, round_trip_load_all
#
#
#  class TestDocument:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_fail.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_fail.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_fail.py:after	2022-04-23 19:39:49.280549
# @@ -7,8 +7,7 @@
#  # and remove remove the xyz_no_fail
#
#  import pytest
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip, round_trip_dump, round_trip_load
#
#
#  class TestCommentFailures:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_float.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_float.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_float.py:after	2022-04-23 19:39:49.290244
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_indentation.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_indentation.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_indentation.py:after	2022-04-23 19:39:49.318304
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, round_trip_dump, dedent, YAML
# +from roundtrip import (YAML, dedent, round_trip, round_trip_dump,
# +                       round_trip_load)
#
#
#  def rt(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_int.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_int.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_int.py:after	2022-04-23 19:39:49.328319
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import dedent, round_trip_load, round_trip_dump
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#  # http://yaml.org/type/int.html is where underscores in integers are defined
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_issues.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_issues.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_issues.py:after	2022-04-23 19:39:49.356899
# @@ -1,17 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -
# -from roundtrip import (
# -    round_trip,
# -    na_round_trip,
# -    round_trip_load,
# -    round_trip_dump,
# -    dedent,
# -    save_and_run,
# -    YAML,
# -)  # NOQA
# +from roundtrip import (YAML, dedent, na_round_trip, round_trip,  # NOQA
# +                       round_trip_dump, round_trip_load, save_and_run)
#
#
#  class TestIssues:
# @@ -412,16 +403,18 @@
#              yaml.load('{]')
#
#      def test_issue_233(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('{}')
#          json_str = json.dumps(data)  # NOQA
#
#      def test_issue_233a(self):
# -        from ruamel.yaml import YAML
#          import json
# +
# +        from ruamel.yaml import YAML
#
#          yaml = YAML()
#          data = yaml.load('[]')
# @@ -577,10 +570,11 @@
#          assert buf.getvalue() == inp
#
#      def test_issue_280(self):
# -        from ruamel.yaml import YAML
# -        from ruamel.yaml.representer import RepresenterError
#          from collections import namedtuple
#          from sys import stdout
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.representer import RepresenterError
#          T = namedtuple('T', ('a', 'b'))
#          t = T(1, 2)
#          yaml = YAML()
# @@ -650,8 +644,9 @@
#
#      def test_issue_288(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -681,8 +676,9 @@
#
#      def test_issue_288a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -712,8 +708,9 @@
#
#      def test_issue_290(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# @@ -748,8 +745,9 @@
#
#      def test_issue_290a(self):
#          import sys
# -        from ruamel.yaml.compat import StringIO
# -        from ruamel.yaml import YAML
# +
# +        from ruamel.yaml import YAML
# +        from ruamel.yaml.compat import StringIO
#
#          yamldoc = dedent("""\
#          ---
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py:after	2022-04-23 19:39:49.371180
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
# +import json
# +
#  import pytest  # NOQA
# -
# -import json
#
#
#  def load(s, typ=float):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_line_col.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_line_col.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_line_col.py:after	2022-04-23 19:39:49.382101
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  def load(s):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_literal.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_literal.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_literal.py:after	2022-04-23 19:39:49.394352
# @@ -1,9 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import YAML  # does an automatic dedent on load
# -
#
#  """
#  YAML 1.0 allowed root level literal style without indentation:
# @@ -63,6 +61,7 @@
#
#      def test_root_literal_scalar_no_indent_1_1_old_style(self):
#          from textwrap import dedent
# +
#          from ruamel.yaml import YAML
#
#          yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_none.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_none.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_none.py:after	2022-04-23 19:39:49.406774
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -from roundtrip import round_trip_load, round_trip_dump
# +from roundtrip import round_trip_dump, round_trip_load
#
#
#  class TestNone:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_program_config.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_program_config.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_program_config.py:after	2022-04-23 19:39:49.436704
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  # import ruamel.yaml
#  from roundtrip import round_trip
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py:after	2022-04-23 19:39:49.447809
# @@ -1,7 +1,7 @@
#  # coding: utf-8
#
# +import pytest  # NOQA
#  from roundtrip import YAML
# -import pytest  # NOQA
#
#
#  def test_example_2_1():
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_string.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_string.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_string.py:after	2022-04-23 19:39:49.470146
# @@ -13,11 +13,12 @@
#
#  """
#
# +import platform
# +
#  import pytest
# -import platform
# -
#  # from ruamel.yaml.compat import ordereddict
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestLiteralScalarString:
# @@ -189,11 +190,11 @@
#          assert round_trip_dump(data) == dedent(exp)
#
#      def test_map(self):
# +        from ruamel.yaml.comments import CommentedMap
#          from ruamel.yaml.compat import ordereddict
# -        from ruamel.yaml.comments import CommentedMap
# -        from ruamel.yaml.scalarstring import walk_tree, preserve_literal
#          from ruamel.yaml.scalarstring import DoubleQuotedScalarString as dq
#          from ruamel.yaml.scalarstring import SingleQuotedScalarString as sq
# +        from ruamel.yaml.scalarstring import preserve_literal, walk_tree
#
#          data = CommentedMap()
#          data[1] = 'a'
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_tag.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_tag.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_tag.py:after	2022-04-23 19:39:49.481724
# @@ -1,8 +1,7 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip, round_trip_load, YAML
# +from roundtrip import YAML, round_trip, round_trip_load
#
#
#  def register_xxx(**kw):
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_version.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_version.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_version.py:after	2022-04-23 19:39:49.493599
# @@ -1,7 +1,6 @@
#  # coding: utf-8
#
#  import pytest  # NOQA
# -
#  from roundtrip import dedent, round_trip, round_trip_load
#
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py:after	2022-04-23 19:39:49.516523
# @@ -4,12 +4,13 @@
#  various test cases for YAML files
#  """
#
# +import io
# +import platform
#  import sys
# -import io
# +
#  import pytest  # NOQA
# -import platform
# -
# -from roundtrip import round_trip, dedent, round_trip_load, round_trip_dump  # NOQA
# +from roundtrip import (dedent, round_trip, round_trip_dump,  # NOQA
# +                       round_trip_load)
#
#
#  class TestYAML:
# @@ -21,8 +22,8 @@
#
#      def test_omap_out(self):
#          # ordereddict mapped to !!omap
# +        import ruamel.yaml  # NOQA
#          from ruamel.yaml.compat import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          x = ordereddict([('a', 1), ('b', 2)])
#          res = round_trip_dump(x, default_flow_style=False)
# @@ -44,6 +45,7 @@
#      @pytest.mark.skipif(sys.version_info < (2, 7), reason='collections not available')
#      def test_dump_collections_ordereddict(self):
#          from collections import OrderedDict
# +
#          import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
# @@ -60,8 +62,8 @@
#          reason='ruamel.yaml not available',
#      )
#      def test_dump_ruamel_ordereddict(self):
# +        import ruamel.yaml  # NOQA
#          from ruamel.ordereddict import ordereddict
# -        import ruamel.yaml  # NOQA
#
#          # OrderedDict mapped to !!omap
#          x = ordereddict([('a', 1), ('b', 2)])
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py:after	2022-04-23 19:39:49.530272
# @@ -1,8 +1,8 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
#  from roundtrip import save_and_run  # NOQA
#
#
# @@ -70,8 +70,8 @@
#  @pytest.mark.skipif(sys.version_info < (3, 0), reason='no __qualname__')
#  def test_qualified_name01(tmpdir):
#      """issue 214"""
# +    import ruamel.yaml.comments
#      from ruamel.yaml import YAML
# -    import ruamel.yaml.comments
#      from ruamel.yaml.compat import StringIO
#
#      yaml = YAML(typ='unsafe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:before	2022-02-12 08:52:13
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py:after	2022-04-23 19:39:49.540146
# @@ -1,9 +1,9 @@
#  # coding: utf-8
#
#  import sys
# +
#  import pytest  # NOQA
# -
# -from roundtrip import round_trip_load, round_trip_dump, dedent
# +from roundtrip import dedent, round_trip_dump, round_trip_load
#
#
#  class TestLeftOverDebug:
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_data.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_data.py:before	2022-04-22 05:17:20.984309
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_data.py:after	2022-04-23 19:39:49.564192
# @@ -1,11 +1,11 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# -import pytest  # NOQA
#  import warnings  # NOQA
#  from pathlib import Path
#
# +import pytest  # NOQA
#  from ruamel.yaml.compat import _F
#
#  base_path = Path('data')  # that is ruamel.yaml.data
# ERROR: /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:before	2022-04-22 05:17:12.268005
# +++ /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py:after	2022-04-23 19:39:49.601126
# @@ -1,13 +1,13 @@
#  # coding: utf-8
#
# +import os
#  import sys
# -import os
# +
#  import pytest  # NOQA
#
#  sys.path.insert(0, os.path.dirname(__file__) + '/lib')
#
#  import warnings  # NOQA
# -
#
#  args = []
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_all.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_all.py:after	2022-04-23 19:39:51.218596
# @@ -1,5 +1,6 @@
#
#  import sys  # NOQA
# +
#  import ruamel.yaml
#  import test_appliance
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:before	2022-04-22 05:22:10.705259
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py:after	2022-04-23 19:39:51.234897
# @@ -1,10 +1,10 @@
#
# +import argparse
# +import os
# +import pprint
#  import sys
# -import os
# +import traceback
#  import types
# -import traceback
# -import pprint
# -import argparse
#
#  # DATA = 'tests/data'
#  # determine the position of data dynamically relative to program
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build.py:after	2022-04-23 19:39:51.249166
# @@ -1,8 +1,8 @@
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -10,7 +10,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml
# -    import test_appliance
#
#      test_appliance.run(test_yaml)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py:after	2022-04-23 19:39:51.262962
# @@ -1,9 +1,9 @@
#
#
#  if __name__ == '__main__':
# +    import distutils.util
# +    import os
#      import sys
# -    import os
# -    import distutils.util
#
#      build_lib = 'build/lib'
#      build_lib_ext = os.path.join(
# @@ -11,7 +11,7 @@
#      )
#      sys.path.insert(0, build_lib)
#      sys.path.insert(0, build_lib_ext)
# +    import test_appliance
#      import test_yaml_ext
# -    import test_appliance
#
#      test_appliance.run(test_yaml_ext)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py:after	2022-04-23 19:39:51.283189
# @@ -1,7 +1,7 @@
#
#
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
#
#
#  def test_canonical_scanner(canonical_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py:after	2022-04-23 19:39:51.314403
# @@ -1,13 +1,14 @@
# +
# +import datetime
# +import pprint
#
#  import ruamel.yaml
# -import pprint
# -
# -import datetime
#
#  try:
#      set
#  except NameError:
#      from sets import Set as set  # NOQA
# +
#  import ruamel.yaml.tokens
#
#
# @@ -364,6 +365,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_constructor  # NOQA
#
#      sys.modules['test_constructor'] = sys.modules['__main__']
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py:after	2022-04-23 19:39:51.330672
# @@ -1,5 +1,4 @@
# -from __future__ import absolute_import
# -from __future__ import print_function
# +from __future__ import absolute_import, print_function
#
#  import ruamel.yaml as yaml
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py:after	2022-04-23 19:39:51.362308
# @@ -1,9 +1,11 @@
#
#  import ruamel.yaml
# +
#  YAML = ruamel.yaml.YAML
#
# +import warnings
# +
#  import test_emitter
# -import warnings
#
#  warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:before	2022-04-22 05:22:10.720884
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py:after	2022-04-23 19:39:51.379618
# @@ -1,10 +1,12 @@
# +
# +import codecs
# +import os
# +import os.path
# +import tempfile
#
#  from ruamel.yaml import YAML
# -import codecs
# -import tempfile
# -import os
# -import os.path
# -from ruamel.yaml.compat import StringIO, BytesIO
# +from ruamel.yaml.compat import BytesIO, StringIO
# +
#
#  def test_unicode_input(unicode_filename, verbose=False):
#      yaml = YAML(typ='safe', pure=True)
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:before	2022-04-22 05:22:10.737925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py:after	2022-04-23 19:39:51.451130
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import test_constructor
#  from ruamel.yaml import YAML
# -import test_constructor
# -import pprint
#
#
#  def test_representer_types(code_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:before	2022-04-22 05:22:10.738925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py:after	2022-04-23 19:39:51.467495
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml as yaml
# -import pprint
#
#
#  def test_implicit_resolver(data_filename, detect_filename, verbose=False):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:before	2022-04-22 05:22:10.739925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py:after	2022-04-23 19:39:51.484250
# @@ -1,7 +1,8 @@
#
# +import pprint
# +
# +import canonical  # NOQA
#  import ruamel.yaml
# -import canonical  # NOQA
# -import pprint
#
#
#  def _convert_structure(loader):
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:before	2022-04-22 05:22:10.741924
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py:after	2022-04-23 19:39:51.501719
# @@ -1,6 +1,7 @@
# +
# +import pprint
#
#  import ruamel.yaml
# -import pprint
#
#  # Tokens mnemonic:
#  # directive:            %
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:before	2022-04-22 05:22:10.742925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py:after	2022-04-23 19:39:51.582807
# @@ -1,20 +1,21 @@
#  # coding: utf-8
#
# +from test_canonical import *  # NOQA
# +from test_constructor import *  # NOQA
# +from test_emitter import *  # NOQA
# +from test_errors import *  # NOQA
# +from test_input_output import *  # NOQA
#  from test_mark import *  # NOQA
#  from test_reader import *  # NOQA
# -from test_canonical import *  # NOQA
# +from test_recursive import *  # NOQA
# +from test_representer import *  # NOQA
# +from test_resolver import *  # NOQA
# +from test_structure import *  # NOQA
#  from test_tokens import *  # NOQA
# -from test_structure import *  # NOQA
# -from test_errors import *  # NOQA
# -from test_resolver import *  # NOQA
# -from test_constructor import *  # NOQA
# -from test_emitter import *  # NOQA
# -from test_representer import *  # NOQA
# -from test_recursive import *  # NOQA
# -from test_input_output import *  # NOQA
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))
# ERROR: /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:before	2022-04-22 05:22:10.744925
# +++ /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py:after	2022-04-23 19:39:51.605783
# @@ -1,9 +1,10 @@
#  # coding: utf-8
# +
# +import pprint
# +import types
#
#  import _ruamel_yaml
#  import ruamel.yaml
# -import types
# -import pprint
#
#  ruamel.yaml.PyBaseLoader = ruamel.yaml.BaseLoader
#  ruamel.yaml.PySafeLoader = ruamel.yaml.SafeLoader
# @@ -369,15 +370,15 @@
#          globals()[function.__name__] = function
#
#
# -import test_tokens  # NOQA
# -import test_structure  # NOQA
# -import test_errors  # NOQA
# -import test_resolver  # NOQA
#  import test_constructor  # NOQA
#  import test_emitter  # NOQA
# +import test_errors  # NOQA
# +import test_input_output  # NOQA
# +import test_recursive  # NOQA
#  import test_representer  # NOQA
# -import test_recursive  # NOQA
# -import test_input_output  # NOQA
# +import test_resolver  # NOQA
# +import test_structure  # NOQA
# +import test_tokens  # NOQA
#
#  wrap_ext(
#      [
# @@ -395,6 +396,7 @@
#
#  if __name__ == '__main__':
#      import sys
# +
#      import test_appliance
#
#      sys.exit(test_appliance.run(globals()))

# %%
# isort setup ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df setup.py
# Out:
# Broken 1 paths

# %% [markdown]
# ---
#
# ### `twine`

# %%
# twine check dist/* ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && twine check .tox/dist/*
# Out:
# ERROR    InvalidDistribution: Cannot find file (or expand pattern):
#          '.tox/dist/*'

# %%
#! check-manifest  # needs `apt-get install python3-venv`

# %% [markdown]
# ---
#
# ## Fixers: `isort`, `black`, and `mypy`
#
# __[testenv:fixers]__
#
# Fix - Readability and style enforcement.
#
# Minimal Requirements:
#
# - fix all warnings
# - gradual typing

# %%
# versions used for testing ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! python --version
! black --version
! isort --version
! mypy --version
! pip freeze | grep mypy-extensions
! pip freeze | grep types-PyYAML
# Out:
# Python 3.10.4
# black, 22.3.0 (compiled: yes)
#
#                  _                 _
#                 (_) ___  ___  _ __| |_
#                 | |/ _/ / _ \/ '__  _/
#                 | |\__ \/\_\/| |  | |_
#                 |_|\___/\___/\_/   \_/
#
#       isort your imports, so you don't have to.
#
#                     VERSION 5.10.1
#
# mypy 0.942
# mypy-extensions==0.4.3
# types-PyYAML==6.0.7

# %% [markdown]
# ---
#
# ### `isort`

# %%
# isort all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort pydantic/ tests/ setup.py
# Out:
# Fixing /workspaces/ruamel-yaml-dev/tests/roundtrip.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_add_xxx.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_anchor.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_api_change.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_collections.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_comments.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_comment_manipulation.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_contextmanager.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_copy.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_cyaml.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_datetime.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_deprecation.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_documents.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_fail.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_float.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_indentation.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_int.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_issues.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_json_numbers.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_line_col.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_literal.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_none.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_program_config.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_spec_examples.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_string.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_tag.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_version.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_yamlfile.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_yamlobject.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_z_check_debug_leftovers.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_z_data.py
# Fixing /workspaces/ruamel-yaml-dev/tests/test_z_olddata.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_all.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_appliance.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_build.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_build_ext.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_canonical.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_constructor.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_emitter.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_errors.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_input_output.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_representer.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_resolver.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_structure.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_tokens.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_yaml.py
# Fixing /workspaces/ruamel-yaml-dev/tests/lib/test_yaml_ext.py
# Broken 2 paths

# %% [markdown]
# ---
#
# ### `black`

# %%
# black all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd ..&& black --version && black pydantic/ tests/ setup.py
# Out:
# black, 22.3.0 (compiled: yes)
# Usage: black [OPTIONS] SRC ...
# Try 'black -h' for help.
#
# Error: Invalid value for 'SRC ...': Path 'pydantic/' does not exist.

# %% [markdown]
# ---
#
# ## `mypy`
#
# Run `mypy` on the `/src` and `tests`
#
# - gradual typing

# %%
# mypy pydantic ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd ../src && mypy vsclint
# Out:
# mypy: can't read file 'vsclint': No such file or directory

# %%
# mypy tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && mypy tests
# Out:
# tests/lib/test_tokens.py:66: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_tokens.py:82: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_resolver.py:27: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_resolver.py:87: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_resolver.py:106: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_recursive.py:53: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_reader.py:39: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_mark.py:30: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_input_output.py:34: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_input_output.py:65: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_input_output.py:119: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_input_output.py:151: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_input_output.py:177: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_emitter.py:31: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_emitter.py:46: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_emitter.py:81: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_constructor.py:10: error: Cannot find implementation or library stub for module named "sets"
# tests/lib/test_constructor.py:10: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# tests/lib/test_constructor.py:264: error: Skipping analyzing "ruamel.ordereddict": module is installed, but missing library stubs or py.typed marker
# tests/lib/test_constructor.py:270: error: Name "ordereddict" already defined (possibly by an import)
# tests/lib/test_constructor.py:330: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_constructor.py:363: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/canonical.py:338: error: Module has no attribute "CanonicalLoader"
# tests/lib/canonical.py:347: error: Module has no attribute "canonical_scan"
# tests/lib/canonical.py:354: error: Module has no attribute "canonical_parse"
# tests/lib/canonical.py:361: error: Module has no attribute "canonical_compose"
# tests/lib/canonical.py:368: error: Module has no attribute "canonical_compose_all"
# tests/lib/canonical.py:375: error: Module has no attribute "canonical_load"
# tests/lib/canonical.py:384: error: Module has no attribute "canonical_load_all"
# tests/lib/test_structure.py:67: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_structure.py:100: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_structure.py:120: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_structure.py:157: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_structure.py:220: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_representer.py:47: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_errors.py:25: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_errors.py:40: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_errors.py:55: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_errors.py:71: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_errors.py:89: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_canonical.py:17: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_canonical.py:30: error: "Callable[[Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_canonical.py:45: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_canonical.py:46: error: "Callable[[Any, Any, Any], Any]" has no attribute "skip"
# tests/test_numpy.py:6: error: Incompatible types in assignment (expression has type "None", variable has type Module)
# tests/lib/test_yaml_ext.py:6: error: Cannot find implementation or library stub for module named "_ruamel_yaml"
# tests/lib/test_yaml_ext.py:9: error: Module has no attribute "PyBaseLoader"; maybe "BaseLoader" or "CBaseLoader"?
# tests/lib/test_yaml_ext.py:10: error: Module has no attribute "PySafeLoader"; maybe "SafeLoader" or "CSafeLoader"?
# tests/lib/test_yaml_ext.py:11: error: Module has no attribute "PyLoader"; maybe "Loader" or "CLoader"?
# tests/lib/test_yaml_ext.py:12: error: Module has no attribute "PyBaseDumper"; maybe "BaseDumper" or "CBaseDumper"?
# tests/lib/test_yaml_ext.py:13: error: Module has no attribute "PySafeDumper"; maybe "SafeDumper" or "CSafeDumper"?
# tests/lib/test_yaml_ext.py:14: error: Module has no attribute "PyDumper"; maybe "Dumper" or "CDumper"?
# tests/lib/test_yaml_ext.py:235: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_yaml_ext.py:236: error: "Callable[[Any, Any, Any], Any]" has no attribute "skip"
# tests/lib/test_yaml_ext.py:283: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_yaml_ext.py:284: error: "Callable[[Any, Any, Any], Any]" has no attribute "skip"
# tests/lib/test_yaml_ext.py:339: error: "Callable[[Any, Any, Any], Any]" has no attribute "unittest"
# tests/lib/test_yaml_ext.py:340: error: "Callable[[Any, Any, Any], Any]" has no attribute "skip"
# tests/lib/test_yaml.py:10: error: Incompatible import of "AnInstance" (imported name has type "Type[test_recursive.AnInstance]", local name has type "Type[test_constructor.AnInstance@146]")
# tests/lib/test_yaml.py:12: error: Incompatible import of "MyLoader" (imported name has type "Type[test_resolver.MyLoader@33]", local name has type "Type[test_constructor.MyLoader@24]")
# tests/lib/test_yaml.py:12: error: Incompatible import of "MyDumper" (imported name has type "Type[test_resolver.MyDumper@36]", local name has type "Type[test_constructor.MyDumper@27]")
# tests/lib/test_yaml.py:13: error: Name "test_constructor" already defined (by an import)
# tests/lib/test_yaml.py:13: error: Incompatible import of "MyLoader" (imported name has type "Type[test_structure.MyLoader@163]", local name has type "Type[test_constructor.MyLoader@24]")
# tests/test_z_olddata.py:12: error: Need type annotation for "args" (hint: "args: List[<type>] = ...")
# tests/test_yamlfile.py:66: error: Skipping analyzing "ruamel.ordereddict": module is installed, but missing library stubs or py.typed marker
# Found 64 errors in 18 files (checked 55 source files)

# %% [markdown]
# Full check on type hinting.

# %%
# mypy --config-file ../mypy_full_check.ini -p vsclint ~~~~~~~~~~~~~~~~~~
! cd ../src && mypy --config-file ../mypy_full_check.ini -p vsclint
# Out:
# usage: mypy [-h] [-v] [-V] [more options; see below]
#             [-m MODULE] [-p PACKAGE] [-c PROGRAM_TEXT] [files ...]
# mypy: error: Cannot find config file '../mypy_full_check.ini'

# %%
# mypy --config-file mypy_full_check.ini -p tests ~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && mypy --config-file mypy_full_check.ini -p tests
# Out:
# usage: mypy [-h] [-v] [-V] [more options; see below]
#             [-m MODULE] [-p PACKAGE] [-c PROGRAM_TEXT] [files ...]
# mypy: error: Cannot find config file 'mypy_full_check.ini'

# %% [markdown]
# ---
#
# ## [`tox.ini`](../tox.ini)
#
# OK, if everything in the above testing is 'good' then your ready to run a full tox matrix.
#
# >Note: The full `tox` matrix can take alot of time so only run this when you are ready to push changes to the repository.

# %%
ready_to_recreate_and_run_tox = True  # set to True when your ready
if ready_to_recreate_and_run_tox:
    # force recreation of virtual environments (-r or --recreate)
    ! cd .. && sudo tox -r > tox_run_r.md
# Out:
# ERROR: tox config file (either pyproject.toml, tox.ini, setup.cfg) not found

# %%
ready_to_run_tox = True  # set to True when your ready
if ready_to_run_tox:
    # use existing virtual environment (only build if not present)
    ! cd .. && sudo tox > tox_run.md
# Out:
# ERROR: tox config file (either pyproject.toml, tox.ini, setup.cfg) not found

# %% [markdown]
# ---
